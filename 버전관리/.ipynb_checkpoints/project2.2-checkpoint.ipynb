# %% [markdown]
# # 토마토 가격 예측

# %% [markdown]
# - 토마토마(김준회, 연제호, 정다영, 추영은)
# - 발표일 : 2020년 3월 19일

# %% [markdown]
# # 1. 서론

# %% [markdown]
# ### 1) 분석 배경

# %% [markdown]
# 최근 몇년간 미세먼지에 대한 관심이 높아졌다. 미세먼지는 황사처럼 하늘을 부옇게 만들고 먼거리까지 이동한다는 점에서 매우 비슷하나 주로 봄에 영향을 주는 황사와 달리 일년 내내 영향을 주며 발생 과정과 특성 역시 많은 차이가 있다. 미세먼지는 가정의 난방과 취사, 자동차 운행, 공장에서의 화석연료의 사용, 산불 및 화전 경작 등으로 발생한 인위적인 입자로 크기는 황사보다 훨씬 작은 2㎛(마이크로미터) 이하이다. 지름 10㎛ 이하의 먼지는 체내에 흡수되어 다양한 질병의 원인이 된다는 내용이 널리 알려져 마스크가 생활화되었다.
#
# 미세먼지는 인체 뿐만 아니라 농가에도 피해를 주고 있다. 비닐하우스에서 재배하는 식물의 경우 농가에서 비닐하우스 위에 내려앉은 미세먼지를 자주 걷어내기 어렵고 유리온실도 마찬가지로 미세먼지으로 인한 투광량이 떨어져 작물의 상품성과 생산성이 떨어진다는 것이다. 특히, 토마토의 경우 노지보다는 하우스 시설에서 재배하고 있고 저장성이 약한데다가 국내 생산 의존도가 높아 어느 농산물 보다 가격 변동이 크다고 한다.

# %% [markdown]
# ### 2) 분석 목적

# %% [markdown]
# 미세먼지에 따른 일조량의 변화와 토마토 생산량 및 가격을 예측하고자 한다.

# %% [markdown]
# ## 2. 데이터 준비

# %% [markdown]
# ### 1) 활용 데이터
#
#  데이터 | 사용 변수 | 시점 | 출처 | 파일 형식
# :---:|:-------:|:---:|:---:|:--------:
# 토마토 일별 품목별 도.소매가격정보 | 품목명, 품종명,	시군구,	마켓명,	연도,	날짜,	가격 | 일 | [농산물유통정보](https://kdx.kr/kamis/periodProductList) | csv
# 대기오염 최종확정자료  | 지역, 측정소코드, 측정소명, 측정일시, SO2, CO, O3, NO2, PM10 | 시간 | [AirKorea](https://www.airkorea.or.kr/web/last_amb_hour_data?pMENU_NO=123) | xlsx
# 종관기상관측(ASOS) | 지점명,	일시,	합계 일조시간 | 일 | [기상청 기상자료개방포털](https://data.kma.go.kr/data/grnd/selectAsosRltmList.do?pgmNo=36) | csv

# %% [markdown]
# #### 종관기상관측(ASOS) 변수 설명
#
#  - 합계 일조시간 : 태양 광선이 구름이나 안개로 가려지지 않고 땅 위를 비친 시간

# %% [markdown]
# #### 대기오염 최종확정자료
#
#  - SO2 : 아황산가스
#  - CO : 이산화탄소
#  - O3 : 오존
#  - NO2 : 이산화질소
#  - PM10 : 미세먼지

# %% [markdown]
# ## 3. 데이터 가공

# %% [markdown]
# #### 필요한 라이브러리 불러오기

# %%
import pandas as pd # 데이터 프레임
import numpy as np # 계산
import re # 정규표현식

import warnings
warnings.filterwarnings('ignore') # warning 메시지 제거

import seaborn as sns # 시각화
import graphviz # 시각화

# %% [markdown]
# #### 시각화를 위한 한글 폰트 설정하기

# %%
import matplotlib.pyplot as plt

# 한글 폰트 지정
plt.rc('font', family='AppleGothic') # 맥
# plt.rc('font', family='Malgun Gothic') # 윈도우

# 마이너스 값 깨지는 현상 해결
plt.rc('axes', unicode_minus=False)

# 레티나 디스플레이 설정
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')

# %% [markdown]
# #### 작업 경로 지정

# %%
import os # wd 변경

# os로 작업 경로 지정
# os.chdir('D:/5 Project/GitHub/CollaborationWork/jyeon94/Learning_Spoons_Second_Project/data/')
os.chdir('/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Second_Project/data')

# %% [markdown]
# ### 1) 대기 오염 데이터

# %%
# 빈 리스트 생성하기
# list_Data = []

# %%
# 컬럼 위치를 변경하기 위해 reColindex 함수 생성

def reColindex(df, ori, fix):
    cols = df.columns.tolist()
    tmp = cols[fix - 1]
    del cols[fix - 1]
    cols.insert(ori - 1, tmp)
    return df[cols]

# %%
# 필요없는 컬럼 삭제 / 시간별을 날짜별로 처리 / 그룹화 하여 평균 처리하기 위한 DataModify 함수 생성

# def DataModify(list_D):
#     if "망" in list_D[len(list_Data) - 1].columns.tolist() :
#         list_D[len(list_Data) - 1] = list_D[len(list_Data) - 1].drop(['망'], axis = 1) 
#     list_D[-1]["측정일시"] = list_Data[-1]["측정일시"].astype(str).str.slice(start = 0, stop = -2)
#     list_D[-1] = list_D[-1].groupby(["지역", "측정소코드", "측정소명", "측정일시"]).mean().reset_index()

# %%
# 파일 경로 변수에 저장
# str_Root = "D:/5 Project/GitHub/CollaborationWork/jyeon94/Learning_Spoons_Second_Project/"
# str_Root = '/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Second_Project/data'

# %% [markdown]
# * **2013년 데이터 중 이상데이터 -999 값이 존재**
# → 측정되지 않은 것으로 추측, 0으로 변경

# %%
# 2013년 데이터 전처리

# str_File = str_Root + "air/2013년0X분기"
# for i in range(4) :
#     list_Data.append(pd.read_excel(str_File.replace('X', str(i + 1)) + ".xlsx"))
#     list_Data[i] = reColindex(list_Data[i], 3, 2)
#     list_Data[i]['PM25'] = np.nan
#     list_Data[i] = reColindex(list_Data[i], 11, 10)

#     # 안됨. 이유를 아직 모르겠음.
#     #    for j in range(6) :
#     #        list_Data[i].iloc[list_Data[i][j + 4] == -999, j + 4] = 0
#     #        print(j + 4, " ", "컬럼 수정 완료" )

#     # 그래서 루프를 돌릴 수 없어서 하드 코딩 처리함.
#     list_Data[i].loc[list_Data[i]["SO2"] == -999, "SO2"] = 0
#     list_Data[i].loc[list_Data[i]["CO"] == -999, "CO"] = 0
#     list_Data[i].loc[list_Data[i]["O3"] == -999, "O3"] = 0
#     list_Data[i].loc[list_Data[i]["NO2"] == -999, "NO2"] = 0
#     list_Data[i].loc[list_Data[i]["PM10"] == -999, "PM10"] = 0    
#     list_Data[i].loc[list_Data[i]["PM25"] == -999, "PM25"] = 0        
#     DataModify(list_Data)
    
# print(len(list_Data))
# list_Data[len(list_Data) - 1].head()

# %%
# 제대로 처리 되었는지 테스트
# list_Data[3].loc[list_Data[3]["SO2"] < 0, "SO2"]
# 비어있는 시리즈가 나온다면 제대로 처리됨.

# %%
# 2014년 데이터 전처리

# str_File = str_Root + "air/2014년 X분기"
# for i in range(4) :
#     list_Data.append(pd.read_csv(str_File.replace('X', str(i + 1)) + ".csv", encoding = 'EUC-KR'))
#     DataModify(list_Data)
    
# print(len(list_Data))
# list_Data[len(list_Data) - 1].head()

# %%
# 2015년 데이터 전처리

# str_File = str_Root + 'air/2015년X분기'
# for i in range(4) :
#     list_Data.append(pd.read_csv(str_File.replace('X', str(i + 1)) + ".csv"))
#     DataModify(list_Data)

# print(len(list_Data))
# list_Data[len(list_Data) - 1].head()

# %%
# 2016년 데이터 전처리

# str_File = str_Root + 'air/2016년 X분기'
# for i in range(4) :
#     list_Data.append(pd.read_csv(str_File.replace('X', str(i + 1)) + ".csv", encoding = 'EUC-KR'))
#     DataModify(list_Data)

# print(len(list_Data))
# list_Data[len(list_Data) - 1].head()

# %%
# 2017년 데이터 전처리

# str_File = str_Root + 'air/2017년 X월'
# for i in range(12) :
#     list_Data.append(pd.read_excel(str_File.replace('X', str(i + 1)) + ".xlsx"))
#     DataModify(list_Data)
    
# print(len(list_Data))

# list_Data[len(list_Data) - 1].head()

# %%
# 2018년 데이터 전처리

# str_File = str_Root + 'air/2018년 X분기'
# for i in range(4) :
#     list_Data.append(pd.read_excel(str_File.replace('X', str(i + 1)) + ".xlsx"))
#     DataModify(list_Data)
    
# print(len(list_Data))
# list_Data[len(list_Data) - 1].head()

# %%
# 데이터 병합
# df = pd.concat(list_Data)

# %%
# 날짜 데이터 타입 변경
# df["측정일시"] = pd.to_datetime(df["측정일시"])
# df.sort_values(by=["측정일시", "지역"], axis=0, ascending = True)

# %%
# 최종 확인
# df[df["PM10"] == 0]

# %%
# 용량이 크기 때문에 csv파일로 저장 후 다시 불러올 예정
# df.to_csv("/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Second_Project/data/날씨_시계열_데이터.csv", encoding = "CP949", index = False)

# %%
# 저장한 날씨 데이터를 불러와 변수 df로 저장
df = pd.read_csv('날씨_시계열_데이터.csv', encoding='euc-kr')

# %%
# 측정일시 컬럼의 연월일을 연도, 월일로 나누기
df['연도'] = df['측정일시'].str.split("-").str.get(0)
df['월'] = df['측정일시'].str.split("-").str.get(1)
df['일'] = df['측정일시'].str.split("-").str.get(2)

# %%
# 토마토 도매가격, 일조량과 컬럼명을 동일하게 하기 위해 측정일시 컬렴명을 일시로 변경
df.rename(columns={'측정일시':'일시'}, inplace=True)

# %%
#null값 처리를 위해 날짜 컬럼 생성
df['날짜'] = df['월'] + '-' + df['일']

#날짜별 PM25 평균을 구해서 df_mean에 담기
df_mean = df.groupby('날짜')['PM25'].mean().reset_index()

#df_mean 제대로 생성되었는지 확인
df_mean

#날짜를 키로 PM25를 value로 딕셔러니 생성
fill_na = dict(zip(df_mean['날짜'],df_mean['PM25']))

#PM25의 null값들을 dictionary value로 채움
df.loc[df['PM25'].isnull(), 'PM25'] = df['날짜'].map(fill_na)

# %%
# 딕셔너리 생성
dic_Sido = {"서울" : "서울특별시",
            "부산" : "부산광역시",
            "대구" : "대구광역시",
            "인천" : "인천광역시",
            "광주" : "광주광역시",
            "대전" : "대전광역시",
            "울산" : "울산광역시",
            "세종" : "세종특별시",
            "경기" : "경기도",
            "강원" : "강원도",
            "충북" : "충청북도",
            "충남" : "충청남도",
            "전북" : "전라북도",
            "전남" : "전라남도",
            "경북" : "경상북도",
            "경남" : "경상남도",
            "제주" : "제주도"}

# 지역을 쪼개서 도로 저장
df['도'] = df["지역"].str.split(" ").str.get(0)

# %%
# 딕셔너리 데이터를 map 함수에 사용하여 key 값과 같은 값들은 전부 value 값으로 변경
df["도"] = df["도"].map(dic_Sido)

# %%
df = df.drop(['지역', '측정소코드'], axis = 1)
df
# Out:
#        측정소명          일시       SO2        CO        O3       NO2       PM10  \
# 0       옥천동  2013-01-01  0.009875  0.579167  0.020958  0.013125  41.333333
# 1       옥천동  2013-01-02  0.007125  0.479167  0.026750  0.007000  36.166667
# 2       옥천동  2013-01-03  0.006167  0.437500  0.024708  0.009125  26.500000
# 3       옥천동  2013-01-04  0.007292  0.608333  0.016833  0.019417  38.708333
# 4       옥천동  2013-01-05  0.007792  0.595833  0.025167  0.007667  36.250000
# ...     ...         ...       ...       ...       ...       ...        ...
# 721266  칠금동  2018-12-27  0.003917  0.300000  0.019042  0.022417  38.458333
# 721267  칠금동  2018-12-28  0.004333  0.375000  0.011667  0.027292  43.708333
# 721268  칠금동  2018-12-29  0.004500  0.479167  0.011750  0.030500  50.833333
# 721269  칠금동  2018-12-30  0.004375  0.487500  0.012917  0.025750  45.041667
# 721270  칠금동  2018-12-31  0.005542  0.779167  0.005208  0.034417  63.958333
#
#              PM25    연도   월   일     날짜     도
# 0       31.543635  2013  01  01  01-01   강원도
# 1       37.602906  2013  01  02  01-02   강원도
# 2       35.062375  2013  01  03  01-03   강원도
# 3       37.749110  2013  01  04  01-04   강원도
# 4       33.378771  2013  01  05  01-05   강원도
# ...           ...   ...  ..  ..    ...   ...
# 721266  10.666667  2018  12  27  12-27  충청북도
# 721267  15.666667  2018  12  28  12-28  충청북도
# 721268  17.166667  2018  12  29  12-29  충청북도
# 721269  21.250000  2018  12  30  12-30  충청북도
# 721270  37.375000  2018  12  31  12-31  충청북도
#
# [721271 rows x 13 columns]

# %%
df = reColindex(df, 1, 13)
df = reColindex(df, 4, 10)
df = reColindex(df, 5, 11)
df = reColindex(df, 6, 12)
df = reColindex(df, 7, 13)

# %%
# 데이터 확인
df
# Out:
#            도 측정소명          일시    연도   월   일     날짜       SO2        CO  \
# 0        강원도  옥천동  2013-01-01  2013  01  01  01-01  0.009875  0.579167
# 1        강원도  옥천동  2013-01-02  2013  01  02  01-02  0.007125  0.479167
# 2        강원도  옥천동  2013-01-03  2013  01  03  01-03  0.006167  0.437500
# 3        강원도  옥천동  2013-01-04  2013  01  04  01-04  0.007292  0.608333
# 4        강원도  옥천동  2013-01-05  2013  01  05  01-05  0.007792  0.595833
# ...      ...  ...         ...   ...  ..  ..    ...       ...       ...
# 721266  충청북도  칠금동  2018-12-27  2018  12  27  12-27  0.003917  0.300000
# 721267  충청북도  칠금동  2018-12-28  2018  12  28  12-28  0.004333  0.375000
# 721268  충청북도  칠금동  2018-12-29  2018  12  29  12-29  0.004500  0.479167
# 721269  충청북도  칠금동  2018-12-30  2018  12  30  12-30  0.004375  0.487500
# 721270  충청북도  칠금동  2018-12-31  2018  12  31  12-31  0.005542  0.779167
#
#               O3       NO2       PM10       PM25
# 0       0.020958  0.013125  41.333333  31.543635
# 1       0.026750  0.007000  36.166667  37.602906
# 2       0.024708  0.009125  26.500000  35.062375
# 3       0.016833  0.019417  38.708333  37.749110
# 4       0.025167  0.007667  36.250000  33.378771
# ...          ...       ...        ...        ...
# 721266  0.019042  0.022417  38.458333  10.666667
# 721267  0.011667  0.027292  43.708333  15.666667
# 721268  0.011750  0.030500  50.833333  17.166667
# 721269  0.012917  0.025750  45.041667  21.250000
# 721270  0.005208  0.034417  63.958333  37.375000
#
# [721271 rows x 13 columns]

# %%
# 데이터 저장
# df.to_csv('/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Second_Project/data/날씨_시계열.csv')

# %% [markdown]
# ### 2)  일조량 데이터

# %%
# 일조량 데이터 불러오기
df_s = pd.read_csv('OBS_ASOS_DD_20200304204217.csv', encoding='euc-kr')

# 불러온 일조량 데이터 확인
df_s.head()
# Out:
#    지점 지점명          일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  \
# 0  90  속초  2013-01-01      -2.0      -6.7          641.0       2.5
# 1  90  속초  2013-01-02      -7.0      -9.8         2341.0      -1.3
# 2  90  속초  2013-01-03      -7.6     -11.5          716.0      -3.1
# 3  90  속초  2013-01-04      -5.2     -10.4          640.0       0.3
# 4  90  속초  2013-01-05      -1.8      -7.4          124.0       1.9
#
#    최고기온 시각(hhmi)  강수 계속시간(hr)  10분 최다 강수량(mm)  ...  0.5m 지중온도(°C)  \
# 0         1352.0         0.75             NaN  ...            NaN
# 1            1.0         1.17             NaN  ...            NaN
# 2         1346.0          NaN             NaN  ...            NaN
# 3         1253.0          NaN             NaN  ...            NaN
# 4         1430.0          NaN             NaN  ...            NaN
#
#    1.0m 지중온도(°C)  1.5m 지중온도(°C)  3.0m 지중온도(°C)  5.0m 지중온도(°C)  합계 대형증발량(mm)  \
# 0            NaN            NaN            NaN            NaN           NaN
# 1            NaN            NaN            NaN            NaN           NaN
# 2            NaN            NaN            NaN            NaN           NaN
# 3            NaN            NaN            NaN            NaN           NaN
# 4            NaN            NaN            NaN            NaN           NaN
#
#    합계 소형증발량(mm)  9-9강수(mm)                                                 기사  \
# 0           NaN        NaN  {눈}1010-1025. {눈}1050-1115. {눈}2355-{눈}{강도0}2400-
# 1           NaN        NaN                                         -{눈}-0110.
# 2           NaN        NaN                                                NaN
# 3           NaN        NaN                                                NaN
# 4           NaN        NaN                                                NaN
#
#    안개 계속시간(hr)
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 62 columns]

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240395 entries, 0 to 240394
# Data columns (total 62 columns):
# 지점                     240395 non-null int64
# 지점명                    240395 non-null object
# 일시                     240395 non-null object
# 평균기온(°C)               240134 non-null float64
# 최저기온(°C)               240356 non-null float64
# 최저기온 시각(hhmi)          240364 non-null float64
# 최고기온(°C)               240361 non-null float64
# 최고기온 시각(hhmi)          240365 non-null float64
# 강수 계속시간(hr)            27016 non-null float64
# 10분 최다 강수량(mm)         54349 non-null float64
# 10분 최다강수량 시각(hhmi)     39813 non-null float64
# 1시간 최다강수량(mm)          54357 non-null float64
# 1시간 최다 강수량 시각(hhmi)    41139 non-null float64
# 일강수량(mm)               87133 non-null float64
# 최대 순간 풍속(m/s)          240280 non-null float64
# 최대 순간 풍속 풍향(16방위)      240282 non-null float64
# 최대 순간풍속 시각(hhmi)       240286 non-null float64
# 최대 풍속(m/s)             240269 non-null float64
# 최대 풍속 풍향(16방위)         240278 non-null float64
# 최대 풍속 시각(hhmi)         240282 non-null float64
# 평균 풍속(m/s)             240204 non-null float64
# 풍정합(100m)              240189 non-null float64
# 최다풍향(16방위)             238872 non-null float64
# 평균 이슬점온도(°C)           239979 non-null float64
# 최소 상대습도(%)             240286 non-null float64
# 최소 상대습도 시각(hhmi)       240294 non-null float64
# 평균 상대습도(%)             239952 non-null float64
# 평균 증기압(hPa)            239949 non-null float64
# 평균 현지기압(hPa)           240088 non-null float64
# 최고 해면기압(hPa)           240315 non-null float64
# 최고 해면기압 시각(hhmi)       240328 non-null float64
# 최저 해면기압(hPa)           240314 non-null float64
# 최저 해면기압 시각(hhmi)       240329 non-null float64
# 평균 해면기압(hPa)           240081 non-null float64
# 가조시간(hr)               240361 non-null float64
# 합계 일조시간(hr)            240012 non-null float64
# 1시간 최다일사 시각(hhmi)      102421 non-null float64
# 1시간 최다일사량(MJ/m2)       102378 non-null float64
# 합계 일사량(MJ/m2)          102388 non-null float64
# 일 최심신적설(cm)            2163 non-null float64
# 일 최심신적설 시각(hhmi)       2146 non-null float64
# 일 최심적설(cm)             3603 non-null float64
# 일 최심적설 시각(hhmi)        3592 non-null float64
# 합계 3시간 신적설(cm)         2241 non-null float64
# 평균 전운량(1/10)           109836 non-null float64
# 평균 중하층운량(1/10)         104376 non-null float64
# 평균 지면온도(°C)            240235 non-null float64
# 최저 초상온도(°C)            240222 non-null float64
# 평균 5cm 지중온도(°C)        71755 non-null float64
# 평균 10cm 지중온도(°C)       71728 non-null float64
# 평균 20cm 지중온도(°C)       71814 non-null float64
# 평균 30cm 지중온도(°C)       71749 non-null float64
# 0.5m 지중온도(°C)          35462 non-null float64
# 1.0m 지중온도(°C)          35471 non-null float64
# 1.5m 지중온도(°C)          32031 non-null float64
# 3.0m 지중온도(°C)          32025 non-null float64
# 5.0m 지중온도(°C)          32024 non-null float64
# 합계 대형증발량(mm)           67821 non-null float64
# 합계 소형증발량(mm)           77913 non-null float64
# 9-9강수(mm)              19522 non-null float64
# 기사                     49637 non-null object
# 안개 계속시간(hr)            5420 non-null float64
# dtypes: float64(58), int64(1), object(3)
# memory usage: 113.7+ MB

# %%
df_s['합계 일조시간(hr)'].isnull().sum()
# Out:
# 383

# %%
# 도로 분류하기 위해 '지점명' 확인
df_s['지점명']
# Out:
# 0         속초
# 1         속초
# 2         속초
# 3         속초
# 4         속초
#           ..
# 240390    남해
# 240391    남해
# 240392    남해
# 240393    남해
# 240394    남해
# Name: 지점명, Length: 240395, dtype: object

# %%
# 지점명에 붙은 접사 제거
df_s['지점명'] = df_s['지점명'].str.replace('시$','').str.replace('군$','').str.replace(r'\(.*?\)','').str.replace('^북','')

# %%
# 도시명의 정식 명칭을 dic 변수에 저장
dic = {'서울':'서울특별시','인천':'인천광역시','부산':'부산광역시',
      '대구':'대구광역시','광주':'광주광역시','대전':'대전광역시',
      '부산':'부산광역시','제주':'제주특별자치도','세종':'세종특별자치시',
      '울산':'울산광역시'}

# %%
# '지점명' 컬럼 내 도시명을 정식 명칭으로 변경
df_s['지점명'].replace(dic, inplace=True)

# %%
# 일조량 데이터는 광역시,특별시,특별자치시 및 특별자치도의
# 시군구의 데이터가 안나와 있기 때문에 제거를 위한 리스트 dic을 이용해 생성
remove = list(dic.values())

# %%
# 도 컬럼을 추가하기 위해 행정구역 현황 데이터 불러오기
df_d = pd.read_csv('행정구역_현황_20200310195900.csv', encoding='euc-kr')

# %%
# 사용할 데이터의 범위만 선택
df_d = df_d[2:]

# %%
# 소계 row는 사용하지 않기 때문에 제거 
df_l = df_d[~df_d['소재지(시군구)별(2)'].str.contains('소계')]

# %%
# 광역시,특별시, 특별자치시 및 특별자치도 데이터 제거
df_l= df_l[~df_l['소재지(시군구)별(1)'].isin(remove)]

# %%
# 일조량 데이터의 지점명과 맞추기 위해 시,군 제거
df_l['소재지(시군구)별(2)']= df_l['소재지(시군구)별(2)'].str.replace(r'시$','').str.replace(r'군$','')

# %%
# 제거가 잘 되었는지 확인 
df_l['소재지(시군구)별(2)'].unique()
# Out:
# array(['수원', '성남', '고양', '용인', '부천', '안산', '안양', '남양주', '화성', '평택', '의정부',
#        '시흥', '파주', '광명', '김포', '군포', '광주', '이천', '양주', '오산', '구리', '안성',
#        '포천', '의왕', '하남', '여주', '양평', '동두천', '과천', '가평', '연천', '춘천', '원주',
#        '강릉', '동해', '태백', '속초', '삼척', '홍천', '횡성', '영월', '평창', '정선', '철원',
#        '화천', '양구', '인제', '고성', '양양', '청주', '충주', '제천', '보은', '옥천', '영동',
#        '진천', '괴산', '음성', '단양', '증평', '천안', '공주', '보령', '아산', '서산', '논산',
#        '계룡', '당진', '금산', '부여', '서천', '청양', '홍성', '예산', '태안', '전주', '군산',
#        '익산', '정읍', '남원', '김제', '완주', '진안', '무주', '장수', '임실', '순창', '고창',
#        '부안', '목포', '여수', '순천', '나주', '광양', '담양', '곡성', '구례', '고흥', '보성',
#        '화순', '장흥', '강진', '해남', '영암', '무안', '함평', '영광', '장성', '완도', '진도',
#        '신안', '포항', '경주', '김천', '안동', '구미', '영주', '영천', '상주', '문경', '경산',
#        '군위', '의성', '청송', '영양', '영덕', '청도', '고령', '성주', '칠곡', '예천', '봉화',
#        '울진', '울릉', '창원', '진주', '통영', '사천', '김해', '밀양', '거제', '양산', '의령',
#        '함안', '창녕', '남해', '하동', '산청', '함양', '거창', '합천'], dtype=object)

# %%
# '도' 리스트 생성
시군구_lst = list(df_l['소재지(시군구)별(1)'].unique())

# %%
# 도별 행정구역 리스틀 만들기 위해 도별 번호 부여
[print(i,j) for i,j in enumerate(시군구_lst) ]
# Out:
# 0 경기도
# 1 강원도
# 2 충청북도
# 3 충청남도
# 4 전라북도
# 5 전라남도
# 6 경상북도
# 7 경상남도
# [None, None, None, None, None, None, None, None]

# %%
# 부여된 번호를 활용하여 각 도별 행정구역 리스트 생성

경기도 = []
강원도 = [] 
충청북도 = []
충청남도 = []
전라북도 = []
전라남도 = []
경상북도 = []
경상남도 = [] 

for i in range(len(시군구_lst)):
    if 시군구_lst[i] == '경기도':
        경기도.append(df_l.loc[df_l['소재지(시군구)별(1)']==시군구_lst[0],'소재지(시군구)별(2)'].to_list())
    elif 시군구_lst[i] == '강원도':
        강원도.append(df_l.loc[df_l['소재지(시군구)별(1)']==시군구_lst[1],'소재지(시군구)별(2)'].to_list())
    elif 시군구_lst[i] == '충청북도':
        충청북도.append(df_l.loc[df_l['소재지(시군구)별(1)']==시군구_lst[2],'소재지(시군구)별(2)'].to_list())
    elif 시군구_lst[i] == '충청남도':
        충청남도.append(df_l.loc[df_l['소재지(시군구)별(1)']==시군구_lst[3],'소재지(시군구)별(2)'].to_list())
    elif 시군구_lst[i] == '전라북도':
        전라북도.append(df_l.loc[df_l['소재지(시군구)별(1)']==시군구_lst[4],'소재지(시군구)별(2)'].to_list())
    elif 시군구_lst[i] == '전라남도':
        전라남도.append(df_l.loc[df_l['소재지(시군구)별(1)']==시군구_lst[5],'소재지(시군구)별(2)'].to_list())
    elif 시군구_lst[i] == '경상북도':
        경상북도.append( df_l.loc[df_l['소재지(시군구)별(1)']==시군구_lst[6],'소재지(시군구)별(2)'].to_list())
    elif 시군구_lst[i] == '경상남도':
        경상남도.append(df_l.loc[df_l['소재지(시군구)별(1)']==시군구_lst[7],'소재지(시군구)별(2)'].to_list())

# %%
# 밑의 코드를 돌려본 결과 행정구역이 명확하지 않은 행정구역들 null 처리되어 행정구역 추가
강원도.append('대관령')
경상북도.append('울릉도')
경상북도.append('추풍령')
전라남도.append('흑산도')
전라북도.append('고산')
제주도 = ['서귀포','성산']
인천광역시 = ['백령도','강화']

# %%
# isin을 활용하여 지점명이 리스트에 있을 경우 그 리스트 이름을 '도' 컬럼에 할당
df_s.loc[df_s['지점명'].isin(경기도[0]),'도'] = '경기도'
df_s.loc[df_s['지점명'].isin(강원도[0]),'도'] = '강원도'
df_s.loc[df_s['지점명'].isin(충청북도[0]),'도'] = '충청북도'
df_s.loc[df_s['지점명'].isin(충청남도[0]),'도'] = '충청남도'
df_s.loc[df_s['지점명'].isin(전라북도[0]),'도'] = '전라북도'
df_s.loc[df_s['지점명'].isin(전라남도[0]),'도'] = '전라남도'
df_s.loc[df_s['지점명'].isin(경상북도[0]),'도'] = '경상북도'
df_s.loc[df_s['지점명'].isin(경상남도[0]),'도'] = '경상남도'
df_s.loc[df_s['지점명'].isin(제주도),'도'] = '제주특별자치도'
df_s.loc[df_s['지점명'].isin(인천광역시),'도'] = '인천광역시'

# %%
# 특별시, 광역시, 특별자치도는 지점명의 값을 '도' 컬럼 값에 할당
df_s['도'] = df_s['도'].fillna(df_s['지점명'])

# %%
# 2019년 데이터 제외
df_s = df_s[~df_s['일시'].str.contains('2019')]

# %%
# 사용할 컬럼만 가져오기
df_use = df_s[['도', '지점명', '일시','합계 일조시간(hr)']].copy()

# %% [markdown]
# * **합계 일조시간(hr)에서 309개 관측값 없음**
# → 해당 일에 합계 일조시간이 없는 것으로 추측, 0으로 처리

# %%
# 결측값을 0으로 채우기
df_use['합계 일조시간(hr)'] = df_use['합계 일조시간(hr)'].fillna(0)

# %%
# merge함수를 사용하기 위해 일시를 연도와 날짜 컬럼으로 나누기
df_use['연도'] = df_use['일시'].str.split('-').str.get(0)
df_use['월'] = df_use['일시'].str.split('-').str.get(1)
df_use['일'] = df_use['일시'].str.split('-').str.get(2)

# %%
# 컬럼 순서 변경
df_use = df_use[['연도', '월', '일', '도', '지점명', '합계 일조시간(hr)', '일시']]

# 확인
df_use.head()
# Out:
#      연도   월   일    도 지점명  합계 일조시간(hr)          일시
# 0  2013  01  01  강원도  속초          5.4  2013-01-01
# 1  2013  01  02  강원도  속초          9.0  2013-01-02
# 2  2013  01  03  강원도  속초          8.9  2013-01-03
# 3  2013  01  04  강원도  속초          9.0  2013-01-04
# 4  2013  01  05  강원도  속초          8.8  2013-01-05

# %%
# 저장
# df.to_csv('/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Second_Project/data/일조량.csv')

# %% [markdown]
# ### 3) 토마토 도매 가격 데이터

# %%
# 토마토 일별 도.소매 가격정보 2013-2016년 데이터 불러오기 
tom36 = pd.read_csv('20132016토마토_일별 품목별 도.소매가격정보.csv')

# 데이터 하단에 있는 평균과 평년 데이터 제외
tomp36 = tom36[(tom36['시군구']!='평균') & (tom36['시군구']!='평년')]

# 데이터 확인
tomp36.head()
# Out:
#    품목명        품종명 시군구   마켓명    연도     날짜      가격
# 0  토마토  토마토(10kg)  서울  가락도매  2013  01/02  29,000
# 1  토마토  토마토(10kg)  서울  가락도매  2013  01/03  30,000
# 2  토마토  토마토(10kg)  서울  가락도매  2013  01/04  30,000
# 3  토마토  토마토(10kg)  서울  가락도매  2013  01/07  30,000
# 4  토마토  토마토(10kg)  서울  가락도매  2013  01/08  27,000

# %%
# 토마토 일별 도.소매 가격정보 2017-2019년 데이터 불러오기 
tom79 = pd.read_csv('20172019토마토_일별 품목별 도.소매가격정보.csv')

# 13-16년 데이터와 마찬가지로 평균 평년 데이터 제외. 2020년 데이터도 제외.
tomp79 = tom79[(tom79['시군구']!='평균') & (tom79['시군구']!='평년') & (tom79['연도']!= 2019) & (tom79['연도']!= 2020)]

# 데이터 확인
tomp79.tail()
# Out:
#       품목명        품종명 시군구   마켓명    연도     날짜      가격
# 4362  토마토  토마토(10kg)  대전  오정도매  2018  12/24  35,000
# 4363  토마토  토마토(10kg)  대전  오정도매  2018  12/26  35,000
# 4364  토마토  토마토(10kg)  대전  오정도매  2018  12/27  35,000
# 4365  토마토  토마토(10kg)  대전  오정도매  2018  12/28  35,000
# 4366  토마토  토마토(10kg)  대전  오정도매  2018  12/31  32,000

# %%
# 데이터 합치기
tomp = pd.concat([tomp36,tomp79])

# 제대로 합쳐졌는지 행 개수 확인
tomp.shape
# Out:
# (7847, 7)

# %%
tomp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7847 entries, 0 to 4366
# Data columns (total 7 columns):
# 품목명    7847 non-null object
# 품종명    7847 non-null object
# 시군구    7847 non-null object
# 마켓명    7847 non-null object
# 연도     7847 non-null int64
# 날짜     7847 non-null object
# 가격     7847 non-null object
# dtypes: int64(1), object(6)
# memory usage: 490.4+ KB

# %%
# 품목명이 모두 토마토이고, 품종명 또한 토마토(10kg)으로 같은 정보를 담고 있으므로 품목명 컬럼을 삭제
tomp = tomp.drop('품목명', axis = 1)

# 데이터 확인
tomp.head()
# Out:
#          품종명 시군구   마켓명    연도     날짜      가격
# 0  토마토(10kg)  서울  가락도매  2013  01/02  29,000
# 1  토마토(10kg)  서울  가락도매  2013  01/03  30,000
# 2  토마토(10kg)  서울  가락도매  2013  01/04  30,000
# 3  토마토(10kg)  서울  가락도매  2013  01/07  30,000
# 4  토마토(10kg)  서울  가락도매  2013  01/08  27,000

# %%
# 시군구, 마켓명, 연도, 날짜 오름차순으로 정렬
tomp = tomp.sort_values(by = ['시군구','마켓명', '연도', '날짜'])

# '시군구' 컬럼명을 '도'로 변경
tomp.rename(columns={'시군구':'도'},inplace=True)

# 데이터 확인
tomp.head()
# Out:
#             품종명   도   마켓명    연도     날짜      가격
# 2955  토마토(10kg)  광주  각화도매  2013  01/02  28,000
# 2956  토마토(10kg)  광주  각화도매  2013  01/03  28,000
# 2957  토마토(10kg)  광주  각화도매  2013  01/04  28,000
# 2958  토마토(10kg)  광주  각화도매  2013  01/07  28,000
# 2959  토마토(10kg)  광주  각화도매  2013  01/08  28,000

# %%
# merge함수를 사용하기 위해 일시를 연도와 날짜 컬럼으로 나누기
tomp['월'] = tomp['날짜'].str.split('/').str.get(0)
tomp['일'] = tomp['날짜'].str.split('/').str.get(1) 

# 데이터 확인
tomp.head()
# Out:
#             품종명   도   마켓명    연도     날짜      가격   월   일
# 2955  토마토(10kg)  광주  각화도매  2013  01/02  28,000  01  02
# 2956  토마토(10kg)  광주  각화도매  2013  01/03  28,000  01  03
# 2957  토마토(10kg)  광주  각화도매  2013  01/04  28,000  01  04
# 2958  토마토(10kg)  광주  각화도매  2013  01/07  28,000  01  07
# 2959  토마토(10kg)  광주  각화도매  2013  01/08  28,000  01  08

# %%
# -을 0으로 변경
tomp['가격'] = tomp['가격'].str.replace('-','0')

# 결측값을 0으로 채우기
tomp['가격'] = tomp['가격'].fillna('0')

# 가격 컬럼의 ,를 제거하고 숫자 타입으로 변환
tomp['가격'] = tomp['가격'].str.replace(',','').astype('int')

# 변경된 컬럼 타입 확인
tomp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7847 entries, 2955 to 486
# Data columns (total 8 columns):
# 품종명    7847 non-null object
# 도      7847 non-null object
# 마켓명    7847 non-null object
# 연도     7847 non-null int64
# 날짜     7847 non-null object
# 가격     7847 non-null int64
# 월      7847 non-null object
# 일      7847 non-null object
# dtypes: int64(2), object(6)
# memory usage: 551.7+ KB

# %%
# 도시명을 정식 명칭으로 변경하기 위해 변수 dic에 저장
dic = {'광주':'광주광역시', '대구':'대구광역시', '대전': '대전광역시', '서울':'서울특별시', '부산':'부산광역시'}

# %%
# '시군구'컬럼의 값을 dic의 값들로 변경
tomp['도'] = tomp['도'].map(dic)

# 변경된 '시군구' 컬럼 확인
tomp.tail()
# Out:
#            품종명      도   마켓명    연도     날짜     가격   월   일
# 482  토마토(10kg)  서울특별시  가락도매  2018  12/24  30000  12  24
# 483  토마토(10kg)  서울특별시  가락도매  2018  12/26  28000  12  26
# 484  토마토(10kg)  서울특별시  가락도매  2018  12/27  26000  12  27
# 485  토마토(10kg)  서울특별시  가락도매  2018  12/28  26000  12  28
# 486  토마토(10kg)  서울특별시  가락도매  2018  12/31  25000  12  31

# %%
# 가격이 없는 서부도매 삭제
tompd = tomp['마켓명'].isin(['서부도매'])
tomp = tomp[~tompd]

# %%
# 연월 컬럼 따로 만들고 날짜 형식으로 바꾸기
tomp['연월'] = tomp['연도'].astype('str') + '-' + tomp['월']
tomp.head()
# Out:
#             품종명      도   마켓명    연도     날짜     가격   월   일       연월
# 2955  토마토(10kg)  광주광역시  각화도매  2013  01/02  28000  01  02  2013-01
# 2956  토마토(10kg)  광주광역시  각화도매  2013  01/03  28000  01  03  2013-01
# 2957  토마토(10kg)  광주광역시  각화도매  2013  01/04  28000  01  04  2013-01
# 2958  토마토(10kg)  광주광역시  각화도매  2013  01/07  28000  01  07  2013-01
# 2959  토마토(10kg)  광주광역시  각화도매  2013  01/08  28000  01  08  2013-01

# %%
# '일시' 컬럼 따로 만들고 날짜 형식으로 바꾸기
tomp['일시'] = tomp['연도'].astype('str') + '-' + tomp['날짜'].str.split('-').str.get(0)
tomp.head()
# Out:
#             품종명      도   마켓명    연도     날짜     가격   월   일       연월          일시
# 2955  토마토(10kg)  광주광역시  각화도매  2013  01/02  28000  01  02  2013-01  2013-01/02
# 2956  토마토(10kg)  광주광역시  각화도매  2013  01/03  28000  01  03  2013-01  2013-01/03
# 2957  토마토(10kg)  광주광역시  각화도매  2013  01/04  28000  01  04  2013-01  2013-01/04
# 2958  토마토(10kg)  광주광역시  각화도매  2013  01/07  28000  01  07  2013-01  2013-01/07
# 2959  토마토(10kg)  광주광역시  각화도매  2013  01/08  28000  01  08  2013-01  2013-01/08

# %%
# 저장
# df.to_csv('/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Second_Project/data/토마토_도매가격.csv')

# %% [markdown]
# ### 4) 데이터 merge

# %%
# 데이터 불러오기
df_sun = pd.read_csv('일조량.csv')
df_tomato = pd.read_csv('토마토_도매가격.csv')
df_time = pd.read_csv('날씨_시계열.csv', encoding='euc-kr')

# %%
# 머신러닝을 위해 도를 int 형식으로 변환을 위한 dictionary
dict_1 = {'강원도':0, '경기도':1, '인천광역시':2, '서울특별시':3, '경상북도':4, '충청북도':5, '충청남도':6, '대전광역시':7,
       '전라북도':8, '대구광역시':9, '울산광역시':10, '경상남도':11, '광주광역시':12, '부산광역시':13, '전라남도':14,
       '제주특별자치도':15}

# %%
# 도_num 컬럼을 dict_1을 이용하여 생성
df_tomato['도_num'] = df_tomato['도'].map(dict_1)
df_sun['도_num'] = df_sun['도'].map(dict_1)
df_time['도_num'] = df_time['도'].map(dict_1)

# %% [markdown]
# * **대기 오염 측정소는 452개, 일조량 측정소는 96개로 merge 시 NaN 발생**
# → ‘일시’와  ‘도’ 기준으로 groupby 처리

# %%
# 세 데이터 merge를 위해 일시 및 도_num으로 groupby하여 평균값 계산
df_s = df_sun.groupby(['일시','도_num']).mean().reset_index()

# %% [markdown]
# * **2013년 ~ 2014년에는 PM2.5(초미세먼지)를 측정하지 않음**
# → 2015년~2018년 데이터의 월과 일 기준 평균값으로 처리

# %%
# 2013년 및 2014년 pm25는 측정값이 없기 때문에 날짜 컬럼을 생성하여 날짜에 따른 PM25 평균값으로 대체 

df_time[['월','일']] = df_time[['월','일']].astype('str') 

# null값 처리를 위해 날짜 컬럼 생성
df_time['날짜'] = df_time['월'] + '-' + df_time['일']

# 날짜별 PM25 평균을 구해서 df_mean에 담기
df_mean = df_time[~df_time['PM25'].isnull()].groupby('날짜')['PM25'].mean().reset_index()

# df_mean 제대로 생성되었는지 확인
df_mean

# 날짜를 키로 PM25를 value로 딕셔러니 생성
fill_na = dict(zip(df_mean['날짜'],df_mean['PM25']))

# PM25의 null값들을 dictionary value로 채움
df_time.loc[df_time['PM25'].isnull(), 'PM25'] = df_time['날짜'].map(fill_na)

# %%
# merge를 위해 날짜 컬럼 drop
df_time = df_time.drop('날짜',axis=1)

# %% [markdown]
# * **2016년부터 세종특별자치시의 대기오염 데이터 측정**
# → 일조량 데이터에는 세종특별자치시 구분이 되어 있지 않아 충청남도로 수정

# %%
# merge를 위해 다른 두 데이터에는 없는 세종시를 충청남도에 포함
df_time.loc[df_time['도'].str.contains('세종'),'도'] = '충청남도'

# %%
# merge를 위해 일시 및 도_num으로 groupby하여 평균값 계산
df_t=df_time.groupby(['일시','도_num']).mean().reset_index()

# %%
# groupby 되었는지 확인
df_t
# Out:
#                일시  도_num    연도       SO2        CO        O3       NO2  \
# 0      2013-01-01    0.0  2013  0.007216  0.770076  0.020583  0.018420
# 1      2013-01-01    1.0  2013  0.006340  0.649199  0.013143  0.031923
# 2      2013-01-01    2.0  2013  0.007477  0.713492  0.013913  0.030154
# 3      2013-01-01    3.0  2013  0.005741  0.658125  0.008458  0.043541
# 4      2013-01-01    4.0  2013  0.006363  0.739583  0.015653  0.017980
# ...           ...    ...   ...       ...       ...       ...       ...
# 32860  2018-12-31   10.0  2018  0.003241  0.502206  0.018193  0.023311
# 32861  2018-12-31   11.0  2018  0.003150  0.475868  0.017313  0.022639
# 32862  2018-12-31   12.0  2018  0.003204  0.605093  0.015468  0.027125
# 32863  2018-12-31   13.0  2018  0.004119  0.373418  0.014718  0.027532
# 32864  2018-12-31   14.0  2018  0.005988  0.594565  0.018808  0.015774
#
#             PM10       PM25
# 0      45.132576  31.543635
# 1      44.532051  31.543635
# 2      39.626984  31.543635
# 3      38.334375  31.543635
# 4      48.280093  31.543635
# ...          ...        ...
# 32860  22.787681  12.066176
# 32861  29.648866  19.518839
# 32862  34.759259  22.728704
# 32863  28.525591  15.960829
# 32864  25.805264  20.055719
#
# [32865 rows x 9 columns]

# %%
# merge를 위해 월,일 컬럼 drop
df_s = df_s.drop(['월','일'],axis=1)

# drop 되었는지 확인
df_s
# Out:
#                일시  도_num    연도  합계 일조시간(hr)
# 0      2013-01-01      0  2013     3.115385
# 1      2013-01-01      1  2013     3.800000
# 2      2013-01-01      2  2013     5.533333
# 3      2013-01-01      3  2013     4.600000
# 4      2013-01-01      4  2013     2.686667
# ...           ...    ...   ...          ...
# 35051  2018-12-31     11  2018     5.921429
# 35052  2018-12-31     12  2018     9.200000
# 35053  2018-12-31     13  2018     5.700000
# 35054  2018-12-31     14  2018     8.471429
# 35055  2018-12-31     15  2018     2.433333
#
# [35056 rows x 4 columns]

# %%
# 일조량 데이터와 대기오염 데이터 merge
df_air = pd.merge(df_t,df_s,on=['일시','도_num','연도'])

# %%
# 데이터 타입 확인
df_air.dtypes
# Out:
# 일시              object
# 도_num          float64
# 연도               int64
# SO2            float64
# CO             float64
# O3             float64
# NO2            float64
# PM10           float64
# PM25           float64
# 합계 일조시간(hr)    float64
# dtype: object

# %%
# merge가 맞게 되었는지 확인
df_air
# Out:
#                일시  도_num    연도       SO2        CO        O3       NO2  \
# 0      2013-01-01    0.0  2013  0.007216  0.770076  0.020583  0.018420
# 1      2013-01-01    1.0  2013  0.006340  0.649199  0.013143  0.031923
# 2      2013-01-01    2.0  2013  0.007477  0.713492  0.013913  0.030154
# 3      2013-01-01    3.0  2013  0.005741  0.658125  0.008458  0.043541
# 4      2013-01-01    4.0  2013  0.006363  0.739583  0.015653  0.017980
# ...           ...    ...   ...       ...       ...       ...       ...
# 32860  2018-12-31   10.0  2018  0.003241  0.502206  0.018193  0.023311
# 32861  2018-12-31   11.0  2018  0.003150  0.475868  0.017313  0.022639
# 32862  2018-12-31   12.0  2018  0.003204  0.605093  0.015468  0.027125
# 32863  2018-12-31   13.0  2018  0.004119  0.373418  0.014718  0.027532
# 32864  2018-12-31   14.0  2018  0.005988  0.594565  0.018808  0.015774
#
#             PM10       PM25  합계 일조시간(hr)
# 0      45.132576  31.543635     3.115385
# 1      44.532051  31.543635     3.800000
# 2      39.626984  31.543635     5.533333
# 3      38.334375  31.543635     4.600000
# 4      48.280093  31.543635     2.686667
# ...          ...        ...          ...
# 32860  22.787681  12.066176     6.600000
# 32861  29.648866  19.518839     5.921429
# 32862  34.759259  22.728704     9.200000
# 32863  28.525591  15.960829     5.700000
# 32864  25.805264  20.055719     8.471429
#
# [32865 rows x 10 columns]

# %%
# 토마토 가격데이터와 기상 데이터 merge (최종 데이터)
df_tomatoma = pd.merge(df_air,df_tomato,on=['일시','도_num','연도'], how='left')

# %%
df_tomatoma[~df_tomatoma['일시'].str.contains('2013|2014|2018')]
# Out:
#                일시  도_num    연도       SO2        CO        O3       NO2  \
# 10950  2015-01-01    0.0  2015  0.004804  0.523007  0.023921  0.009153
# 10951  2015-01-01    1.0  2015  0.004798  0.411294  0.020143  0.011644
# 10952  2015-01-01    2.0  2015  0.004998  0.408929  0.021345  0.009187
# 10953  2015-01-01    3.0  2015  0.005268  0.386432  0.017600  0.014946
# 10954  2015-01-01    4.0  2015  0.004866  0.426097  0.026598  0.005901
# ...           ...    ...   ...       ...       ...       ...       ...
# 27385  2017-12-31   10.0  2017  0.003583  0.700260  0.028560  0.017779
# 27386  2017-12-31   11.0  2017  0.003392  0.557803  0.029622  0.013610
# 27387  2017-12-31   12.0  2017  0.002731  0.600926  0.027796  0.016380
# 27388  2017-12-31   13.0  2017  0.003782  0.399265  0.028774  0.014218
# 27389  2017-12-31   14.0  2017  0.003821  0.625893  0.031497  0.009815
#
#             PM10       PM25  합계 일조시간(hr)  품종명    도  마켓명   날짜  가격   월   일   연월
# 10950  65.045455  24.020192     7.930769  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# 10951  69.002664  28.909265     8.500000  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# 10952  65.023810  27.846832     6.266667  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# 10953  65.684411  19.724415     8.900000  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# 10954  42.131020  31.543635     7.886667  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# ...          ...        ...          ...  ...  ...  ...  ...  ..  ..  ..  ...
# 27385  69.770833  34.403416     8.800000  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# 27386  71.634133  31.628244     7.985714  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# 27387  79.917069  31.310185     6.100000  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# 27388  78.670238  38.210317     8.900000  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
# 27389  63.358709  29.200649     6.085714  NaN  NaN  NaN  NaN NaN NaN NaN  NaN
#
# [16440 rows x 18 columns]

# %%
# 품종명은 토마토 밖에 없기때문에 토마토(10kg)로 nan값 채우기
df_tomatoma['품종명'] = df_tomatoma['품종명'].fillna('토마토(10kg)')

# %%
# 위에 생성된 dictionary의 key값과 value값 변경
dict_reversed = {v: k for k, v in dict_1.items()}

# %%
# float 타입으로 되어있는 도_num int값으로 변경
df_tomatoma['도_num'] = df_tomatoma['도_num'].astype('int')

# %%
# dict_reverse를 이용하여 도 컬럼 생성
df_tomatoma.loc[df_tomatoma['도'].isnull(),'도'] = df_tomatoma['도_num'].map(dict_reversed)

# %% [markdown]
# * **마켓이 열리지 않는 날의 토마토 도매 가격 NaN 발생**
# → 마켓이 열리는 일시의 ‘가격’과 ‘도’를 고려하여 넣음

# %%
# 가격이 없는 일시는 장이 안선 날이기때문에 가격이 null아닌 일시만 list로 변환
change_list = list(df_tomatoma.loc[~df_tomatoma['가격'].isnull(),'일시'].unique())

# %%
# list에 있는 값 확인
change_list
# Out:
# ['2013-01-02',
#  '2013-01-03',
#  '2013-01-04',
#  '2013-01-07',
#  '2013-01-08',
#  '2013-01-09',
#  '2013-01-10',
#  '2013-01-11',
#  '2013-01-14',
#  '2013-01-15',
#  '2013-01-16',
#  '2013-01-17',
#  '2013-01-18',
#  '2013-01-21',
#  '2013-01-22',
#  '2013-01-23',
#  '2013-01-24',
#  '2013-01-25',
#  '2013-01-28',
#  '2013-01-29',
#  '2013-01-30',
#  '2013-01-31',
#  '2013-02-01',
#  '2013-02-04',
#  '2013-02-05',
#  '2013-02-06',
#  '2013-02-07',
#  '2013-02-08',
#  '2013-02-12',
#  '2013-02-13',
#  '2013-02-14',
#  '2013-02-15',
#  '2013-02-18',
#  '2013-02-19',
#  '2013-02-20',
#  '2013-02-21',
#  '2013-02-22',
#  '2013-02-25',
#  '2013-02-26',
#  '2013-02-27',
#  '2013-02-28',
#  '2013-03-04',
#  '2013-03-05',
#  '2013-03-06',
#  '2013-03-07',
#  '2013-03-08',
#  '2013-03-11',
#  '2013-03-12',
#  '2013-03-13',
#  '2013-03-14',
#  '2013-03-15',
#  '2013-03-18',
#  '2013-03-19',
#  '2013-03-20',
#  '2013-03-21',
#  '2013-03-22',
#  '2013-03-25',
#  '2013-03-26',
#  '2013-03-27',
#  '2013-03-28',
#  '2013-03-29',
#  '2013-04-01',
#  '2013-04-02',
#  '2013-04-03',
#  '2013-04-04',
#  '2013-04-05',
#  '2013-04-08',
#  '2013-04-09',
#  '2013-04-10',
#  '2013-04-11',
#  '2013-04-12',
#  '2013-04-15',
#  '2013-04-16',
#  '2013-04-17',
#  '2013-04-18',
#  '2013-04-19',
#  '2013-04-22',
#  '2013-04-23',
#  '2013-04-24',
#  '2013-04-25',
#  '2013-04-26',
#  '2013-04-29',
#  '2013-04-30',
#  '2013-05-02',
#  '2013-05-03',
#  '2013-05-06',
#  '2013-05-07',
#  '2013-05-08',
#  '2013-05-09',
#  '2013-05-10',
#  '2013-05-13',
#  '2013-05-14',
#  '2013-05-15',
#  '2013-05-16',
#  '2013-05-20',
#  '2013-05-21',
#  '2013-05-22',
#  '2013-05-23',
#  '2013-05-24',
#  '2013-05-27',
#  '2013-05-28',
#  '2013-05-29',
#  '2013-05-30',
#  '2013-05-31',
#  '2013-06-03',
#  '2013-06-04',
#  '2013-06-05',
#  '2013-06-07',
#  '2013-06-10',
#  '2013-06-11',
#  '2013-06-12',
#  '2013-06-13',
#  '2013-06-14',
#  '2013-06-17',
#  '2013-06-18',
#  '2013-06-19',
#  '2013-06-20',
#  '2013-06-21',
#  '2013-06-24',
#  '2013-06-25',
#  '2013-06-26',
#  '2013-06-27',
#  '2013-06-28',
#  '2013-07-01',
#  '2013-07-02',
#  '2013-07-03',
#  '2013-07-04',
#  '2013-07-05',
#  '2013-07-08',
#  '2013-07-09',
#  '2013-07-10',
#  '2013-07-11',
#  '2013-07-12',
#  '2013-07-15',
#  '2013-07-16',
#  '2013-07-17',
#  '2013-07-18',
#  '2013-07-19',
#  '2013-07-22',
#  '2013-07-23',
#  '2013-07-24',
#  '2013-07-25',
#  '2013-07-26',
#  '2013-07-29',
#  '2013-07-30',
#  '2013-07-31',
#  '2013-08-01',
#  '2013-08-02',
#  '2013-08-05',
#  '2013-08-06',
#  '2013-08-07',
#  '2013-08-08',
#  '2013-08-09',
#  '2013-08-12',
#  '2013-08-13',
#  '2013-08-14',
#  '2013-08-16',
#  '2013-08-19',
#  '2013-08-20',
#  '2013-08-21',
#  '2013-08-22',
#  '2013-08-23',
#  '2013-08-26',
#  '2013-08-27',
#  '2013-08-28',
#  '2013-08-29',
#  '2013-08-30',
#  '2013-09-02',
#  '2013-09-03',
#  '2013-09-04',
#  '2013-09-05',
#  '2013-09-06',
#  '2013-09-09',
#  '2013-09-10',
#  '2013-09-11',
#  '2013-09-12',
#  '2013-09-13',
#  '2013-09-16',
#  '2013-09-17',
#  '2013-09-23',
#  '2013-09-24',
#  '2013-09-25',
#  '2013-09-26',
#  '2013-09-27',
#  '2013-09-30',
#  '2013-10-01',
#  '2013-10-02',
#  '2013-10-04',
#  '2013-10-07',
#  '2013-10-08',
#  '2013-10-10',
#  '2013-10-11',
#  '2013-10-14',
#  '2013-10-15',
#  '2013-10-16',
#  '2013-10-17',
#  '2013-10-18',
#  '2013-10-21',
#  '2013-10-22',
#  '2013-10-23',
#  '2013-10-24',
#  '2013-10-25',
#  '2013-10-28',
#  '2013-10-29',
#  '2013-10-30',
#  '2013-10-31',
#  '2013-11-01',
#  '2013-11-04',
#  '2013-11-05',
#  '2013-11-06',
#  '2013-11-07',
#  '2013-11-08',
#  '2013-11-11',
#  '2013-11-12',
#  '2013-11-13',
#  '2013-11-14',
#  '2013-11-15',
#  '2013-11-18',
#  '2013-11-19',
#  '2013-11-20',
#  '2013-11-21',
#  '2013-11-22',
#  '2013-11-25',
#  '2013-11-26',
#  '2013-11-27',
#  '2013-11-28',
#  '2013-11-29',
#  '2013-12-02',
#  '2013-12-03',
#  '2013-12-04',
#  '2013-12-05',
#  '2013-12-06',
#  '2013-12-09',
#  '2013-12-10',
#  '2013-12-11',
#  '2013-12-12',
#  '2013-12-13',
#  '2013-12-16',
#  '2013-12-17',
#  '2013-12-18',
#  '2013-12-19',
#  '2013-12-20',
#  '2013-12-23',
#  '2013-12-24',
#  '2013-12-26',
#  '2013-12-27',
#  '2013-12-30',
#  '2013-12-31',
#  '2014-01-02',
#  '2014-01-03',
#  '2014-01-06',
#  '2014-01-07',
#  '2014-01-08',
#  '2014-01-09',
#  '2014-01-10',
#  '2014-01-13',
#  '2014-01-14',
#  '2014-01-15',
#  '2014-01-16',
#  '2014-01-17',
#  '2014-01-20',
#  '2014-01-21',
#  '2014-01-22',
#  '2014-01-23',
#  '2014-01-24',
#  '2014-01-27',
#  '2014-01-28',
#  '2014-01-29',
#  '2014-02-03',
#  '2014-02-04',
#  '2014-02-05',
#  '2014-02-06',
#  '2014-02-07',
#  '2014-02-10',
#  '2014-02-11',
#  '2014-02-12',
#  '2014-02-13',
#  '2014-02-14',
#  '2014-02-17',
#  '2014-02-18',
#  '2014-02-19',
#  '2014-02-20',
#  '2014-02-21',
#  '2014-02-24',
#  '2014-02-25',
#  '2014-02-26',
#  '2014-02-27',
#  '2014-02-28',
#  '2014-03-03',
#  '2014-03-04',
#  '2014-03-05',
#  '2014-03-06',
#  '2014-03-07',
#  '2014-03-10',
#  '2014-03-11',
#  '2014-03-12',
#  '2014-03-13',
#  '2014-03-14',
#  '2014-03-17',
#  '2014-03-18',
#  '2014-03-19',
#  '2014-03-20',
#  '2014-03-21',
#  '2014-03-24',
#  '2014-03-25',
#  '2014-03-26',
#  '2014-03-27',
#  '2014-03-28',
#  '2014-03-31',
#  '2014-04-01',
#  '2014-04-02',
#  '2014-04-03',
#  '2014-04-04',
#  '2014-04-07',
#  '2014-04-08',
#  '2014-04-09',
#  '2014-04-10',
#  '2014-04-11',
#  '2014-04-14',
#  '2014-04-15',
#  '2014-04-16',
#  '2014-04-17',
#  '2014-04-18',
#  '2014-04-21',
#  '2014-04-22',
#  '2014-04-23',
#  '2014-04-24',
#  '2014-04-25',
#  '2014-04-28',
#  '2014-04-29',
#  '2014-04-30',
#  '2014-05-02',
#  '2014-05-07',
#  '2014-05-08',
#  '2014-05-09',
#  '2014-05-12',
#  '2014-05-13',
#  '2014-05-14',
#  '2014-05-15',
#  '2014-05-16',
#  '2014-05-19',
#  '2014-05-20',
#  '2014-05-21',
#  '2014-05-22',
#  '2014-05-23',
#  '2014-05-26',
#  '2014-05-27',
#  '2014-05-28',
#  '2014-05-29',
#  '2014-05-30',
#  '2014-06-02',
#  '2014-06-03',
#  '2014-06-05',
#  '2014-06-09',
#  '2014-06-10',
#  '2014-06-11',
#  '2014-06-12',
#  '2014-06-13',
#  '2014-06-16',
#  '2014-06-17',
#  '2014-06-18',
#  '2014-06-19',
#  '2014-06-20',
#  '2014-06-23',
#  '2014-06-24',
#  '2014-06-25',
#  '2014-06-26',
#  '2014-06-27',
#  '2014-06-30',
#  '2014-07-01',
#  '2014-07-02',
#  '2014-07-03',
#  '2014-07-04',
#  '2014-07-07',
#  '2014-07-08',
#  '2014-07-09',
#  '2014-07-10',
#  '2014-07-11',
#  '2014-07-14',
#  '2014-07-15',
#  '2014-07-16',
#  '2014-07-17',
#  '2014-07-18',
#  '2014-07-21',
#  '2014-07-22',
#  '2014-07-23',
#  '2014-07-24',
#  '2014-07-25',
#  '2014-07-28',
#  '2014-07-29',
#  '2014-07-30',
#  '2014-07-31',
#  '2014-08-04',
#  '2014-08-05',
#  '2014-08-06',
#  '2014-08-07',
#  '2014-08-08',
#  '2014-08-11',
#  '2014-08-12',
#  '2014-08-13',
#  '2014-08-14',
#  '2014-08-18',
#  '2014-08-19',
#  '2014-08-20',
#  '2014-08-21',
#  '2014-08-22',
#  '2014-08-25',
#  '2014-08-26',
#  '2014-08-27',
#  '2014-08-28',
#  '2014-08-29',
#  '2014-09-01',
#  '2014-09-02',
#  '2014-09-03',
#  '2014-09-04',
#  '2014-09-05',
#  '2014-09-11',
#  '2014-09-12',
#  '2014-09-15',
#  '2014-09-17',
#  '2014-09-18',
#  '2014-09-19',
#  '2014-09-22',
#  '2014-09-23',
#  '2014-09-24',
#  '2014-09-25',
#  '2014-09-26',
#  '2014-09-29',
#  '2014-09-30',
#  '2014-10-01',
#  '2014-10-02',
#  '2014-10-06',
#  '2014-10-07',
#  '2014-10-08',
#  '2014-10-10',
#  '2014-10-13',
#  '2014-10-14',
#  '2014-10-15',
#  '2014-10-16',
#  '2014-10-17',
#  '2014-10-20',
#  '2014-10-21',
#  '2014-10-22',
#  '2014-10-23',
#  '2014-10-24',
#  '2014-10-27',
#  '2014-10-28',
#  '2014-10-29',
#  '2014-10-30',
#  '2014-10-31',
#  '2014-11-03',
#  '2014-11-04',
#  '2014-11-05',
#  '2014-11-06',
#  '2014-11-07',
#  '2014-11-10',
#  '2014-11-11',
#  '2014-11-12',
#  '2014-11-13',
#  '2014-11-14',
#  '2014-11-17',
#  '2014-11-18',
#  '2014-11-19',
#  '2014-11-20',
#  '2014-11-21',
#  '2014-11-24',
#  '2014-11-25',
#  '2014-11-26',
#  '2014-11-27',
#  '2014-11-28',
#  '2014-12-02',
#  '2014-12-03',
#  '2014-12-04',
#  '2014-12-05',
#  '2014-12-08',
#  '2014-12-09',
#  '2014-12-10',
#  '2014-12-11',
#  '2014-12-12',
#  '2014-12-15',
#  '2014-12-16',
#  '2014-12-17',
#  '2014-12-18',
#  '2014-12-19',
#  '2014-12-22',
#  '2014-12-23',
#  '2014-12-24',
#  '2014-12-26',
#  '2014-12-29',
#  '2014-12-30',
#  '2014-12-31',
#  '2015-01-02',
#  '2015-01-05',
#  '2015-01-06',
#  '2015-01-07',
#  '2015-01-08',
#  '2015-01-09',
#  '2015-01-12',
#  '2015-01-13',
#  '2015-01-14',
#  '2015-01-15',
#  '2015-01-16',
#  '2015-01-19',
#  '2015-01-20',
#  '2015-01-21',
#  '2015-01-22',
#  '2015-01-23',
#  '2015-01-26',
#  '2015-01-27',
#  '2015-01-28',
#  '2015-01-29',
#  '2015-01-30',
#  '2015-02-02',
#  '2015-02-03',
#  '2015-02-04',
#  '2015-02-05',
#  '2015-02-06',
#  '2015-02-09',
#  '2015-02-10',
#  '2015-02-11',
#  '2015-02-12',
#  '2015-02-13',
#  '2015-02-16',
#  '2015-02-17',
#  '2015-02-23',
#  '2015-02-24',
#  '2015-02-25',
#  '2015-02-26',
#  '2015-02-27',
#  '2015-03-02',
#  '2015-03-03',
#  '2015-03-04',
#  '2015-03-05',
#  '2015-03-06',
#  '2015-03-09',
#  '2015-03-10',
#  '2015-03-11',
#  '2015-03-12',
#  '2015-03-13',
#  '2015-03-16',
#  '2015-03-17',
#  '2015-03-18',
#  '2015-03-19',
#  '2015-03-20',
#  '2015-03-23',
#  '2015-03-24',
#  '2015-03-25',
#  '2015-03-26',
#  '2015-03-27',
#  '2015-03-30',
#  '2015-03-31',
#  '2015-04-01',
#  '2015-04-02',
#  '2015-04-03',
#  '2015-04-06',
#  '2015-04-07',
#  '2015-04-08',
#  '2015-04-09',
#  '2015-04-10',
#  '2015-04-13',
#  '2015-04-14',
#  '2015-04-15',
#  '2015-04-16',
#  '2015-04-17',
#  '2015-04-20',
#  '2015-04-21',
#  '2015-04-22',
#  '2015-04-23',
#  '2015-04-24',
#  '2015-04-27',
#  '2015-04-28',
#  '2015-04-29',
#  '2015-04-30',
#  '2015-05-04',
#  '2015-05-06',
#  '2015-05-07',
#  '2015-05-08',
#  '2015-05-11',
#  '2015-05-12',
#  '2015-05-13',
#  '2015-05-14',
#  '2015-05-15',
#  '2015-05-18',
#  '2015-05-19',
#  '2015-05-20',
#  '2015-05-21',
#  '2015-05-22',
#  '2015-05-26',
#  '2015-05-27',
#  '2015-05-28',
#  '2015-05-29',
#  '2015-06-01',
#  '2015-06-02',
#  '2015-06-03',
#  '2015-06-04',
#  '2015-06-05',
#  '2015-06-08',
#  '2015-06-09',
#  '2015-06-10',
#  '2015-06-11',
#  '2015-06-12',
#  '2015-06-15',
#  '2015-06-16',
#  '2015-06-17',
#  '2015-06-18',
#  '2015-06-19',
#  '2015-06-22',
#  '2015-06-23',
#  '2015-06-24',
#  '2015-06-25',
#  '2015-06-26',
#  '2015-06-29',
#  '2015-06-30',
#  '2015-07-01',
#  '2015-07-02',
#  '2015-07-03',
#  '2015-07-06',
#  '2015-07-07',
#  '2015-07-08',
#  '2015-07-09',
#  '2015-07-10',
#  '2015-07-13',
#  '2015-07-14',
#  '2015-07-15',
#  '2015-07-16',
#  '2015-07-17',
#  '2015-07-20',
#  '2015-07-21',
#  '2015-07-22',
#  '2015-07-23',
#  '2015-07-24',
#  '2015-07-27',
#  '2015-07-28',
#  '2015-07-29',
#  '2015-07-30',
#  '2015-07-31',
#  '2015-08-03',
#  '2015-08-04',
#  '2015-08-05',
#  '2015-08-06',
#  '2015-08-07',
#  '2015-08-10',
#  '2015-08-11',
#  '2015-08-12',
#  '2015-08-13',
#  '2015-08-17',
#  '2015-08-18',
#  '2015-08-19',
#  '2015-08-20',
#  '2015-08-21',
#  '2015-08-24',
#  '2015-08-25',
#  '2015-08-26',
#  '2015-08-27',
#  '2015-08-28',
#  '2015-08-31',
#  '2015-09-01',
#  '2015-09-02',
#  '2015-09-03',
#  '2015-09-04',
#  '2015-09-07',
#  '2015-09-08',
#  '2015-09-09',
#  '2015-09-10',
#  '2015-09-11',
#  '2015-09-14',
#  '2015-09-15',
#  '2015-09-16',
#  '2015-09-17',
#  '2015-09-18',
#  '2015-09-21',
#  '2015-09-22',
#  '2015-09-23',
#  '2015-09-24',
#  '2015-09-25',
#  '2015-09-30',
#  '2015-10-01',
#  '2015-10-02',
#  '2015-10-05',
#  '2015-10-06',
#  '2015-10-07',
#  '2015-10-08',
#  '2015-10-12',
#  '2015-10-13',
#  '2015-10-14',
#  '2015-10-15',
#  '2015-10-16',
#  '2015-10-19',
#  '2015-10-20',
#  '2015-10-21',
#  '2015-10-22',
#  '2015-10-23',
#  '2015-10-26',
#  '2015-10-27',
#  '2015-10-28',
#  '2015-10-29',
#  '2015-10-30',
#  '2015-11-02',
#  '2015-11-03',
#  '2015-11-04',
#  '2015-11-05',
#  '2015-11-06',
#  '2015-11-09',
#  '2015-11-10',
#  '2015-11-11',
#  '2015-11-12',
#  '2015-11-13',
#  '2015-11-16',
#  '2015-11-17',
#  '2015-11-18',
#  '2015-11-19',
#  '2015-11-20',
#  '2015-11-23',
#  '2015-11-24',
#  '2015-11-25',
#  '2015-11-26',
#  '2015-11-27',
#  '2015-11-30',
#  '2015-12-01',
#  '2015-12-02',
#  '2015-12-03',
#  '2015-12-07',
#  '2015-12-08',
#  '2015-12-09',
#  '2015-12-10',
#  '2015-12-11',
#  '2015-12-14',
#  '2015-12-15',
#  '2015-12-16',
#  '2015-12-17',
#  '2015-12-18',
#  '2015-12-21',
#  '2015-12-22',
#  '2015-12-23',
#  '2015-12-24',
#  '2015-12-28',
#  '2015-12-29',
#  '2015-12-30',
#  '2015-12-31',
#  '2016-01-04',
#  '2016-01-05',
#  '2016-01-06',
#  '2016-01-07',
#  '2016-01-08',
#  '2016-01-11',
#  '2016-01-12',
#  '2016-01-13',
#  '2016-01-14',
#  '2016-01-15',
#  '2016-01-18',
#  '2016-01-19',
#  '2016-01-20',
#  '2016-01-21',
#  '2016-01-22',
#  '2016-01-25',
#  '2016-01-26',
#  '2016-01-27',
#  '2016-01-28',
#  '2016-01-29',
#  '2016-02-01',
#  '2016-02-02',
#  '2016-02-03',
#  '2016-02-04',
#  '2016-02-05',
#  '2016-02-11',
#  '2016-02-12',
#  '2016-02-15',
#  '2016-02-16',
#  '2016-02-17',
#  '2016-02-18',
#  '2016-02-19',
#  '2016-02-22',
#  '2016-02-23',
#  '2016-02-24',
#  '2016-02-25',
#  '2016-02-26',
#  '2016-02-29',
#  '2016-03-02',
#  '2016-03-03',
#  '2016-03-04',
#  '2016-03-07',
#  '2016-03-08',
#  '2016-03-09',
#  '2016-03-10',
#  '2016-03-11',
#  '2016-03-14',
#  '2016-03-15',
#  '2016-03-16',
#  '2016-03-17',
#  '2016-03-18',
#  '2016-03-21',
#  '2016-03-22',
#  '2016-03-23',
#  '2016-03-24',
#  '2016-03-25',
#  '2016-03-28',
#  '2016-03-29',
#  '2016-03-30',
#  '2016-03-31',
#  '2016-04-01',
#  '2016-04-04',
#  '2016-04-05',
#  '2016-04-06',
#  '2016-04-07',
#  '2016-04-08',
#  '2016-04-11',
#  '2016-04-12',
#  '2016-04-14',
#  '2016-04-15',
#  '2016-04-18',
#  '2016-04-19',
#  '2016-04-20',
#  '2016-04-21',
#  '2016-04-22',
#  '2016-04-25',
#  '2016-04-26',
#  '2016-04-27',
#  '2016-04-28',
#  '2016-04-29',
#  '2016-05-02',
#  '2016-05-03',
#  '2016-05-04',
#  '2016-05-09',
#  '2016-05-10',
#  '2016-05-11',
#  '2016-05-12',
#  '2016-05-13',
#  '2016-05-16',
#  '2016-05-17',
#  '2016-05-18',
#  '2016-05-19',
#  '2016-05-20',
#  '2016-05-23',
#  '2016-05-24',
#  '2016-05-25',
#  '2016-05-26',
#  '2016-05-27',
#  '2016-05-30',
#  '2016-05-31',
#  '2016-06-01',
#  '2016-06-02',
#  '2016-06-03',
#  '2016-06-07',
#  '2016-06-08',
#  '2016-06-09',
#  '2016-06-10',
#  '2016-06-13',
#  '2016-06-14',
#  '2016-06-15',
#  '2016-06-16',
#  '2016-06-17',
#  '2016-06-20',
#  '2016-06-21',
#  '2016-06-22',
#  '2016-06-23',
#  '2016-06-24',
#  '2016-06-27',
#  '2016-06-28',
#  '2016-06-29',
#  '2016-06-30',
#  '2016-07-01',
#  '2016-07-04',
#  '2016-07-05',
#  '2016-07-06',
#  '2016-07-07',
#  '2016-07-08',
#  '2016-07-11',
#  '2016-07-12',
#  '2016-07-13',
#  '2016-07-14',
#  '2016-07-15',
#  '2016-07-18',
#  '2016-07-19',
#  '2016-07-20',
#  '2016-07-21',
#  '2016-07-22',
#  '2016-07-25',
#  '2016-07-26',
#  '2016-07-27',
#  '2016-07-28',
#  '2016-07-29',
#  '2016-08-01',
#  '2016-08-02',
#  '2016-08-03',
#  '2016-08-04',
#  '2016-08-05',
#  '2016-08-08',
#  '2016-08-09',
#  '2016-08-10',
#  '2016-08-11',
#  '2016-08-12',
#  '2016-08-16',
#  '2016-08-17',
#  '2016-08-18',
#  '2016-08-19',
#  '2016-08-22',
#  '2016-08-23',
#  '2016-08-24',
#  '2016-08-25',
#  '2016-08-26',
#  '2016-08-29',
#  '2016-08-30',
#  '2016-08-31',
#  '2016-09-01',
#  '2016-09-02',
#  '2016-09-05',
#  '2016-09-06',
#  '2016-09-07',
#  '2016-09-08',
#  '2016-09-09',
#  '2016-09-12',
#  '2016-09-13',
#  '2016-09-19',
#  '2016-09-20',
#  '2016-09-21',
#  '2016-09-22',
#  '2016-09-23',
#  '2016-09-26',
#  '2016-09-27',
#  '2016-09-28',
#  '2016-09-29',
#  '2016-09-30',
#  '2016-10-04',
#  '2016-10-05',
#  '2016-10-06',
#  '2016-10-07',
#  '2016-10-10',
#  '2016-10-11',
#  '2016-10-12',
#  '2016-10-13',
#  '2016-10-14',
#  '2016-10-17',
#  '2016-10-18',
#  '2016-10-19',
#  '2016-10-20',
#  '2016-10-21',
#  '2016-10-24',
#  '2016-10-25',
#  '2016-10-26',
#  '2016-10-27',
#  '2016-10-28',
#  '2016-10-31',
#  '2016-11-01',
#  '2016-11-02',
#  '2016-11-03',
#  '2016-11-04',
#  '2016-11-07',
#  '2016-11-08',
#  '2016-11-09',
#  '2016-11-10',
#  '2016-11-11',
#  '2016-11-14',
#  '2016-11-15',
#  '2016-11-16',
#  '2016-11-17',
#  '2016-11-18',
#  '2016-11-21',
#  '2016-11-22',
#  '2016-11-23',
#  '2016-11-24',
#  '2016-11-25',
#  '2016-11-28',
#  '2016-11-29',
#  '2016-11-30',
#  '2016-12-01',
#  '2016-12-05',
#  '2016-12-06',
#  '2016-12-07',
#  '2016-12-08',
#  '2016-12-09',
#  '2016-12-12',
#  '2016-12-13',
#  '2016-12-14',
#  '2016-12-15',
#  '2016-12-16',
#  '2016-12-19',
#  '2016-12-20',
#  '2016-12-21',
#  '2016-12-22',
#  '2016-12-23',
#  '2016-12-26',
#  '2016-12-27',
#  '2016-12-28',
#  '2016-12-29',
#  '2016-12-30',
#  '2017-01-02',
#  '2017-01-03',
#  '2017-01-04',
#  '2017-01-05',
#  '2017-01-06',
#  '2017-01-09',
#  '2017-01-10',
#  '2017-01-11',
#  '2017-01-12',
#  '2017-01-13',
#  '2017-01-16',
#  '2017-01-17',
#  '2017-01-18',
#  '2017-01-19',
#  '2017-01-20',
#  ...]

# %%
df_tomatoma_final = df_tomatoma.copy()

# %%
# 현재 안 쓸 컬럼들 드랍
df_tomatoma_final = df_tomatoma_final.drop(['날짜','월','일','연월'],axis=1)

# %%
# 가격이 nan인 값들을 권역을 설정하여 채워주기 위해 리스트 생성
광주_lst = ['광주광역시','전라북도','전라남도','제주도']
대구_lst = ['대구광역시','경상북도']
부산_lst = ['부산광역시','경상남도','울산광역시']
대전_lst = ['대전광역시','충청북도','충청남도']
서울_lst = ['서울특별시','경기도','강원도','인천광역시']

# %%
# nan값을 채우기 위해 interpolate의  time method를 사용하기 위해 일시를 date type으로 변경
df_tomatoma_final['일시']=pd.to_datetime(df_tomatoma_final['일시'])

# %%
# 일시를 index로 변경
df_tomatoma_final = df_tomatoma_final.set_index('일시')

# %%
# 변경이 되었는지 확인
df_tomatoma_final
# Out:
#             도_num    연도       SO2        CO        O3       NO2       PM10  \
# 일시
# 2013-01-01      0  2013  0.007216  0.770076  0.020583  0.018420  45.132576
# 2013-01-01      1  2013  0.006340  0.649199  0.013143  0.031923  44.532051
# 2013-01-01      2  2013  0.007477  0.713492  0.013913  0.030154  39.626984
# 2013-01-01      3  2013  0.005741  0.658125  0.008458  0.043541  38.334375
# 2013-01-01      4  2013  0.006363  0.739583  0.015653  0.017980  48.280093
# ...           ...   ...       ...       ...       ...       ...        ...
# 2018-12-31     10  2018  0.003241  0.502206  0.018193  0.023311  22.787681
# 2018-12-31     11  2018  0.003150  0.475868  0.017313  0.022639  29.648866
# 2018-12-31     12  2018  0.003204  0.605093  0.015468  0.027125  34.759259
# 2018-12-31     13  2018  0.004119  0.373418  0.014718  0.027532  28.525591
# 2018-12-31     14  2018  0.005988  0.594565  0.018808  0.015774  25.805264
#
#                  PM25  합계 일조시간(hr)        품종명      도   마켓명       가격
# 일시
# 2013-01-01  31.543635     3.115385  토마토(10kg)    강원도   NaN      NaN
# 2013-01-01  31.543635     3.800000  토마토(10kg)    경기도   NaN      NaN
# 2013-01-01  31.543635     5.533333  토마토(10kg)  인천광역시   NaN      NaN
# 2013-01-01  31.543635     4.600000  토마토(10kg)  서울특별시   NaN      NaN
# 2013-01-01  31.543635     2.686667  토마토(10kg)   경상북도   NaN      NaN
# ...               ...          ...        ...    ...   ...      ...
# 2018-12-31  12.066176     6.600000  토마토(10kg)  울산광역시   NaN      NaN
# 2018-12-31  19.518839     5.921429  토마토(10kg)   경상남도   NaN      NaN
# 2018-12-31  22.728704     9.200000  토마토(10kg)  광주광역시  각화도매  31000.0
# 2018-12-31  15.960829     5.700000  토마토(10kg)  부산광역시  엄궁도매  30000.0
# 2018-12-31  20.055719     8.471429  토마토(10kg)   전라남도   NaN      NaN
#
# [32865 rows x 13 columns]

# %% [markdown]
# * **도매 마켓 지역은 5개이나 기상 데이터의 ‘도’는 16개로 merge 시 NaN 발생**
# → 도매 마켓 권역 별로 전국 ‘도’를 5개로 묶음

# %%
# 각 권역의 마켓명이 같을 것이라고 가정하여 fillna의 bfill을 사용하여 마켓명 채우기위한 함수
def fill_market(lst):
    df_tomatoma_final.loc[df_tomatoma_final['도'].isin(lst),'마켓명'] =  df_tomatoma_final.loc[df_tomatoma_final['도'].isin(lst),'마켓명'].fillna(method='bfill')
    return df_tomatoma_final.loc[df_tomatoma_final['도'].isin(lst),'마켓명']

# %%
# 함수를 활용하여 마켓명 nan값 처리
fill_market(광주_lst)
fill_market(대구_lst)
fill_market(부산_lst)
fill_market(대전_lst)
fill_market(서울_lst)
# Out:
# 일시
# 2013-01-01    가락도매
# 2013-01-01    가락도매
# 2013-01-01    가락도매
# 2013-01-01    가락도매
# 2013-01-02    가락도매
#               ...
# 2018-12-30    가락도매
# 2018-12-31    가락도매
# 2018-12-31    가락도매
# 2018-12-31    가락도매
# 2018-12-31    가락도매
# Name: 마켓명, Length: 8764, dtype: object

# %%
# 함수를 사용하였지만 값이 안들어간 마켓명이 존재하여 하드코딩으로 값 채움
df_tomatoma_final.loc[df_tomatoma_final['마켓명'].isnull(),'마켓명'] = '각화도매'

# %%
market_lst
# Out:
# ['가락도매', '북부도매', '오정도매', '각화도매', '엄궁도매']

# %%
# 마켓 별로 분할
market_lst = list(df_tomatoma_final['마켓명'].unique())
def divide_market(lst):
    for i in range(len(lst)):
        globals()['df_{}'.format(lst[i])] = df_tomatoma_final[df_tomatoma_final['마켓명'].str.contains(lst[i])]
        print(lst[i])
    return globals()['df_{}'.format(lst[i])]

# %%
def fill_price(data_frame):
    data_frame.loc[~data_frame.index.isin(change_list),'가격'] = -1
    data_frame.loc[data_frame.index.isin(change_list),'가격'] = data_frame.loc[data_frame.index.isin(change_list),'가격'].interpolate(method='time',limit_direction='both')
    return data_frame

# %%
divide_market(market_lst)
# Out:
# 가락도매
# 북부도매
# 오정도매
# 각화도매
# 엄궁도매
#             도_num    연도       SO2        CO        O3       NO2       PM10  \
# 일시
# 2013-01-01     10  2013  0.010050  0.639722  0.018031  0.024222  57.133333
# 2013-01-01     11  2013  0.008088  0.631884  0.017784  0.025764  77.425725
# 2013-01-01     13  2013  0.008563  0.518651  0.019060  0.025597  71.460317
# 2013-01-02     10  2013  0.008697  0.561111  0.024350  0.019328  61.511111
# 2013-01-02     11  2013  0.006880  0.472645  0.027493  0.014323  66.144928
# ...           ...   ...       ...       ...       ...       ...        ...
# 2018-12-30     11  2018  0.002871  0.394384  0.028389  0.012366  21.276004
# 2018-12-30     13  2018  0.003498  0.314881  0.025540  0.015788  20.628269
# 2018-12-31     10  2018  0.003241  0.502206  0.018193  0.023311  22.787681
# 2018-12-31     11  2018  0.003150  0.475868  0.017313  0.022639  29.648866
# 2018-12-31     13  2018  0.004119  0.373418  0.014718  0.027532  28.525591
#
#                  PM25  합계 일조시간(hr)        품종명      도   마켓명       가격
# 일시
# 2013-01-01  31.543635     7.200000  토마토(10kg)  울산광역시  엄궁도매      NaN
# 2013-01-01  31.543635     4.364286  토마토(10kg)   경상남도  엄궁도매      NaN
# 2013-01-01  31.543635     8.000000  토마토(10kg)  부산광역시  엄궁도매      NaN
# 2013-01-02  37.602906     8.200000  토마토(10kg)  울산광역시  엄궁도매      NaN
# 2013-01-02  37.602906     8.050000  토마토(10kg)   경상남도  엄궁도매      NaN
# ...               ...          ...        ...    ...   ...      ...
# 2018-12-30  17.370242     8.092857  토마토(10kg)   경상남도  엄궁도매      NaN
# 2018-12-30  11.347071     8.800000  토마토(10kg)  부산광역시  엄궁도매      NaN
# 2018-12-31  12.066176     6.600000  토마토(10kg)  울산광역시  엄궁도매      NaN
# 2018-12-31  19.518839     5.921429  토마토(10kg)   경상남도  엄궁도매      NaN
# 2018-12-31  15.960829     5.700000  토마토(10kg)  부산광역시  엄궁도매  30000.0
#
# [6573 rows x 13 columns]

# %%
fill_price(df_가락도매)
fill_price(df_오정도매)
fill_price(df_각화도매)
fill_price(df_북부도매)
fill_price(df_엄궁도매)
# Out:
#             도_num    연도       SO2        CO        O3       NO2       PM10  \
# 일시
# 2013-01-01     10  2013  0.010050  0.639722  0.018031  0.024222  57.133333
# 2013-01-01     11  2013  0.008088  0.631884  0.017784  0.025764  77.425725
# 2013-01-01     13  2013  0.008563  0.518651  0.019060  0.025597  71.460317
# 2013-01-02     10  2013  0.008697  0.561111  0.024350  0.019328  61.511111
# 2013-01-02     11  2013  0.006880  0.472645  0.027493  0.014323  66.144928
# ...           ...   ...       ...       ...       ...       ...        ...
# 2018-12-30     11  2018  0.002871  0.394384  0.028389  0.012366  21.276004
# 2018-12-30     13  2018  0.003498  0.314881  0.025540  0.015788  20.628269
# 2018-12-31     10  2018  0.003241  0.502206  0.018193  0.023311  22.787681
# 2018-12-31     11  2018  0.003150  0.475868  0.017313  0.022639  29.648866
# 2018-12-31     13  2018  0.004119  0.373418  0.014718  0.027532  28.525591
#
#                  PM25  합계 일조시간(hr)        품종명      도   마켓명       가격
# 일시
# 2013-01-01  31.543635     7.200000  토마토(10kg)  울산광역시  엄궁도매     -1.0
# 2013-01-01  31.543635     4.364286  토마토(10kg)   경상남도  엄궁도매     -1.0
# 2013-01-01  31.543635     8.000000  토마토(10kg)  부산광역시  엄궁도매     -1.0
# 2013-01-02  37.602906     8.200000  토마토(10kg)  울산광역시  엄궁도매  28000.0
# 2013-01-02  37.602906     8.050000  토마토(10kg)   경상남도  엄궁도매  28000.0
# ...               ...          ...        ...    ...   ...      ...
# 2018-12-30  17.370242     8.092857  토마토(10kg)   경상남도  엄궁도매     -1.0
# 2018-12-30  11.347071     8.800000  토마토(10kg)  부산광역시  엄궁도매     -1.0
# 2018-12-31  12.066176     6.600000  토마토(10kg)  울산광역시  엄궁도매  30000.0
# 2018-12-31  19.518839     5.921429  토마토(10kg)   경상남도  엄궁도매  30000.0
# 2018-12-31  15.960829     5.700000  토마토(10kg)  부산광역시  엄궁도매  30000.0
#
# [6573 rows x 13 columns]

# %%
# 저장
# df_tomatoma_final.to_csv('data/full_data.csv')

# %%
# 저장한 데이터 확인
# pd.read_csv('data/full_data.csv')

# %% [markdown]
# ### 5) 데이터 분할

# %%
train_data = df_tomatoma_final[df_tomatoma_final['연도'] != 2018]
test_data = df_tomatoma_final[df_tomatoma_final['연도'] == 2018]

# %% [markdown]
# ### 6) 2013년 ~ 2017년 기초 통계

# %%
train_data = train_data.reset_index()
train_data
# Out:
#               일시  도_num    연도       SO2        CO        O3       NO2  \
# 0     2013-01-01      0  2013  0.007216  0.770076  0.020583  0.018420
# 1     2013-01-01      1  2013  0.006340  0.649199  0.013143  0.031923
# 2     2013-01-01      2  2013  0.007477  0.713492  0.013913  0.030154
# 3     2013-01-01      3  2013  0.005741  0.658125  0.008458  0.043541
# 4     2013-01-01      4  2013  0.006363  0.739583  0.015653  0.017980
# ...          ...    ...   ...       ...       ...       ...       ...
# 27385 2017-12-31     10  2017  0.003583  0.700260  0.028560  0.017779
# 27386 2017-12-31     11  2017  0.003392  0.557803  0.029622  0.013610
# 27387 2017-12-31     12  2017  0.002731  0.600926  0.027796  0.016380
# 27388 2017-12-31     13  2017  0.003782  0.399265  0.028774  0.014218
# 27389 2017-12-31     14  2017  0.003821  0.625893  0.031497  0.009815
#
#             PM10       PM25  합계 일조시간(hr)        품종명      도   마켓명  가격
# 0      45.132576  31.543635     3.115385  토마토(10kg)    강원도  가락도매 NaN
# 1      44.532051  31.543635     3.800000  토마토(10kg)    경기도  가락도매 NaN
# 2      39.626984  31.543635     5.533333  토마토(10kg)  인천광역시  가락도매 NaN
# 3      38.334375  31.543635     4.600000  토마토(10kg)  서울특별시  가락도매 NaN
# 4      48.280093  31.543635     2.686667  토마토(10kg)   경상북도  북부도매 NaN
# ...          ...        ...          ...        ...    ...   ...  ..
# 27385  69.770833  34.403416     8.800000  토마토(10kg)  울산광역시  엄궁도매 NaN
# 27386  71.634133  31.628244     7.985714  토마토(10kg)   경상남도  엄궁도매 NaN
# 27387  79.917069  31.310185     6.100000  토마토(10kg)  광주광역시  각화도매 NaN
# 27388  78.670238  38.210317     8.900000  토마토(10kg)  부산광역시  엄궁도매 NaN
# 27389  63.358709  29.200649     6.085714  토마토(10kg)   전라남도  각화도매 NaN
#
# [27390 rows x 14 columns]

# %%
train_data['일시'] = train_data['일시'].astype(str)
train_data['일시']
# Out:
# 0        2013-01-01
# 1        2013-01-01
# 2        2013-01-01
# 3        2013-01-01
# 4        2013-01-01
#             ...
# 27385    2017-12-31
# 27386    2017-12-31
# 27387    2017-12-31
# 27388    2017-12-31
# 27389    2017-12-31
# Name: 일시, Length: 27390, dtype: object

# %%
train_data['연월'] = train_data['일시'].str.split('-').str.get(0) + '-' + train_data['일시'].str.split('-').str.get(1)
train_data.head()
# Out:
#            일시  도_num    연도       SO2        CO        O3       NO2       PM10  \
# 0  2013-01-01      0  2013  0.007216  0.770076  0.020583  0.018420  45.132576
# 1  2013-01-01      1  2013  0.006340  0.649199  0.013143  0.031923  44.532051
# 2  2013-01-01      2  2013  0.007477  0.713492  0.013913  0.030154  39.626984
# 3  2013-01-01      3  2013  0.005741  0.658125  0.008458  0.043541  38.334375
# 4  2013-01-01      4  2013  0.006363  0.739583  0.015653  0.017980  48.280093
#
#         PM25  합계 일조시간(hr)        품종명      도   마켓명  가격       연월
# 0  31.543635     3.115385  토마토(10kg)    강원도  가락도매 NaN  2013-01
# 1  31.543635     3.800000  토마토(10kg)    경기도  가락도매 NaN  2013-01
# 2  31.543635     5.533333  토마토(10kg)  인천광역시  가락도매 NaN  2013-01
# 3  31.543635     4.600000  토마토(10kg)  서울특별시  가락도매 NaN  2013-01
# 4  31.543635     2.686667  토마토(10kg)   경상북도  북부도매 NaN  2013-01

# %%
train_data[['SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25', '합계 일조시간(hr)', '가격']].describe()
# Out:
#                 SO2            CO            O3           NO2          PM10  \
# count  27390.000000  27390.000000  27390.000000  27390.000000  27390.000000
# mean       0.004567      0.492271      0.027812      0.020800     45.702578
# std        0.002041      0.170993      0.012006      0.010142     23.731431
# min        0.001027      0.147096      0.001400      0.003762      4.245370
# 25%        0.003199      0.375474      0.019167      0.013312     30.205190
# 50%        0.004228      0.457055      0.026826      0.018503     41.273764
# 75%        0.005525      0.570164      0.035485      0.026088     55.571013
# max        0.024909      1.983333      0.083800      0.082172    555.692308
#
#                PM25   합계 일조시간(hr)            가격
# count  27390.000000  27390.000000   6140.000000
# mean      24.909677      6.470134  26424.429967
# std        9.123458      3.798046   7837.258151
# min        3.304003      0.000000  10000.000000
# 25%       18.559784      3.271753  20000.000000
# 50%       23.805158      7.300000  27000.000000
# 75%       29.902652      9.480000  32000.000000
# max      101.494905     13.900000  48000.000000

# %% [markdown]
# #### 월 평균 토마토 도매 가격
#
# * **봄(2월) 가격 상승, 여름(6월) 가격 하락**
# → 가격 패턴이 뚜렷한 계절성을 보이고 있음

# %%
plt.figure(figsize=(20,6))
s = plt.xticks(rotation=90)
sns.lineplot(data=train_data, x='연월', y='가격', ci=None, linewidth=2.5)

# %% [markdown]
# #### 월 평균 일조량
#
# * **봄 일조량 상승, 여름, 겨울 일조량 하락**
# → 일조량 패턴이 뚜렷한 계절성을 보이고 있음!

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=90)
sns.lineplot(data=train_data, x='연월', y='합계 일조시간(hr)', ci=None, linewidth=2.5)

# %% [markdown]
# #### 월 평균 대기오염
# * **봄, 겨울 PM10과 PM25 상승, 여름 PM10과 PM25 하락**
# → PM10과 PM25 패턴이 뚜렷한 계절성을 보이고 있음

# %%
ss = train_data[['연월', 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25']]

# %%
ss_1 = ss.groupby(['연월'])['SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'].mean().reset_index()
ss_1
# Out:
#          연월       SO2        CO        O3       NO2       PM10       PM25
# 0   2013-01  0.007208  0.770745  0.017697  0.029585  61.436295  30.900525
# 1   2013-02  0.006048  0.598919  0.022497  0.024870  48.492788  28.882708
# 2   2013-03  0.005526  0.526044  0.029922  0.023834  61.089004  32.543501
# 3   2013-04  0.004825  0.469235  0.036153  0.020936  50.820526  26.171680
# 4   2013-05  0.005120  0.438621  0.038800  0.021190  57.012092  25.056091
# 5   2013-06  0.004753  0.395590  0.034327  0.018814  43.130911  24.502940
# 6   2013-07  0.003804  0.361361  0.025501  0.012898  35.103109  18.512949
# 7   2013-08  0.004129  0.389981  0.027949  0.015106  37.427338  15.773766
# 8   2013-09  0.003737  0.390080  0.025361  0.017223  32.068012  17.109025
# 9   2013-10  0.003603  0.417879  0.021400  0.020130  33.781902  19.363692
# 10  2013-11  0.004546  0.547882  0.017275  0.023737  43.006160  28.962752
# 11  2013-12  0.006084  0.639658  0.015207  0.026342  50.836994  28.088631
# 12  2014-01  0.007231  0.720912  0.016290  0.028871  60.672328  30.900525
# 13  2014-02  0.005667  0.625832  0.022734  0.025403  54.779124  28.882708
# 14  2014-03  0.005413  0.533282  0.030365  0.023452  56.353126  32.543501
# 15  2014-04  0.005224  0.481913  0.036762  0.024614  55.952693  26.171680
# 16  2014-05  0.005063  0.445841  0.046088  0.020091  66.041336  25.056091
# 17  2014-06  0.004185  0.386113  0.038812  0.016752  44.944908  24.502940
# 18  2014-07  0.004088  0.405458  0.032177  0.015587  38.965862  18.512949
# 19  2014-08  0.003671  0.396881  0.026930  0.015024  30.318472  15.773766
# 20  2014-09  0.003917  0.418831  0.027535  0.017561  33.260549  17.109025
# 21  2014-10  0.003907  0.473437  0.022583  0.022197  36.825304  19.363692
# 22  2014-11  0.004778  0.597334  0.017111  0.026788  44.956099  28.962752
# 23  2014-12  0.005632  0.610699  0.016862  0.023370  42.416923  28.088631
# 24  2015-01  0.005787  0.681367  0.016463  0.025281  50.603865  30.305110
# 25  2015-02  0.005670  0.608853  0.023054  0.023162  71.544595  30.237712
# 26  2015-03  0.005800  0.561486  0.028687  0.025198  66.893201  32.093945
# 27  2015-04  0.004659  0.464268  0.033672  0.020817  46.004964  25.454749
# 28  2015-05  0.005281  0.424692  0.041347  0.020489  49.708739  25.933269
# 29  2015-06  0.004597  0.420210  0.040135  0.017479  43.274168  25.608954
# 30  2015-07  0.004008  0.375490  0.029176  0.014341  33.581906  19.426194
# 31  2015-08  0.004014  0.393995  0.030362  0.015415  35.393423  18.402730
# 32  2015-09  0.003568  0.391693  0.028788  0.017167  29.161240  16.946910
# 33  2015-10  0.003893  0.487397  0.025785  0.022433  47.239341  22.549382
# 34  2015-11  0.003899  0.546031  0.016636  0.022764  36.366787  27.186033
# 35  2015-12  0.004838  0.663621  0.014110  0.025834  47.923335  29.476819
# 36  2016-01  0.005076  0.605070  0.018763  0.024125  47.575200  30.755598
# 37  2016-02  0.004903  0.545255  0.024581  0.022057  46.168851  27.798199
# 38  2016-03  0.004794  0.506114  0.029233  0.024167  57.803706  32.513932
# 39  2016-04  0.004575  0.465771  0.036895  0.022375  64.403175  27.761792
# 40  2016-05  0.004698  0.430174  0.044413  0.019847  52.927588  27.037695
# 41  2016-06  0.004176  0.395514  0.039019  0.017204  40.791388  25.217701
# 42  2016-07  0.004013  0.360968  0.027652  0.014847  28.979823  17.764658
# 43  2016-08  0.003819  0.392712  0.033481  0.014927  32.292188  17.521669
# 44  2016-09  0.003495  0.423382  0.028448  0.016777  35.435399  19.865357
# 45  2016-10  0.003481  0.445077  0.021328  0.019880  37.819391  20.295502
# 46  2016-11  0.004121  0.573455  0.017680  0.025216  50.900743  29.780329
# 47  2016-12  0.004448  0.627756  0.015368  0.025609  45.495887  28.887572
# 48  2017-01  0.004557  0.604110  0.020318  0.024151  49.846628  31.250322
# 49  2017-02  0.004518  0.548445  0.025975  0.022949  44.529153  27.629614
# 50  2017-03  0.004720  0.537483  0.033275  0.024158  55.606118  34.200162
# 51  2017-04  0.004344  0.456615  0.040835  0.020014  55.304463  25.855078
# 52  2017-05  0.004543  0.423487  0.043576  0.018773  59.775921  25.358686
# 53  2017-06  0.004231  0.411696  0.043669  0.016476  40.725553  23.749029
# 54  2017-07  0.003648  0.386241  0.030164  0.014218  33.355995  19.487714
# 55  2017-08  0.003328  0.377373  0.027027  0.013455  25.332108  14.080407
# 56  2017-09  0.003335  0.438518  0.031127  0.017307  36.100323  19.931053
# 57  2017-10  0.003160  0.416195  0.024082  0.017566  32.656892  17.961219
# 58  2017-11  0.003882  0.533659  0.019694  0.023873  47.839871  27.502471
# 59  2017-12  0.004118  0.592382  0.017458  0.024243  45.389124  28.433215

# %%
ss_2 = ss_1[['SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25']]
ss_2
# Out:
#          SO2        CO        O3       NO2       PM10       PM25
# 0   0.007208  0.770745  0.017697  0.029585  61.436295  30.900525
# 1   0.006048  0.598919  0.022497  0.024870  48.492788  28.882708
# 2   0.005526  0.526044  0.029922  0.023834  61.089004  32.543501
# 3   0.004825  0.469235  0.036153  0.020936  50.820526  26.171680
# 4   0.005120  0.438621  0.038800  0.021190  57.012092  25.056091
# 5   0.004753  0.395590  0.034327  0.018814  43.130911  24.502940
# 6   0.003804  0.361361  0.025501  0.012898  35.103109  18.512949
# 7   0.004129  0.389981  0.027949  0.015106  37.427338  15.773766
# 8   0.003737  0.390080  0.025361  0.017223  32.068012  17.109025
# 9   0.003603  0.417879  0.021400  0.020130  33.781902  19.363692
# 10  0.004546  0.547882  0.017275  0.023737  43.006160  28.962752
# 11  0.006084  0.639658  0.015207  0.026342  50.836994  28.088631
# 12  0.007231  0.720912  0.016290  0.028871  60.672328  30.900525
# 13  0.005667  0.625832  0.022734  0.025403  54.779124  28.882708
# 14  0.005413  0.533282  0.030365  0.023452  56.353126  32.543501
# 15  0.005224  0.481913  0.036762  0.024614  55.952693  26.171680
# 16  0.005063  0.445841  0.046088  0.020091  66.041336  25.056091
# 17  0.004185  0.386113  0.038812  0.016752  44.944908  24.502940
# 18  0.004088  0.405458  0.032177  0.015587  38.965862  18.512949
# 19  0.003671  0.396881  0.026930  0.015024  30.318472  15.773766
# 20  0.003917  0.418831  0.027535  0.017561  33.260549  17.109025
# 21  0.003907  0.473437  0.022583  0.022197  36.825304  19.363692
# 22  0.004778  0.597334  0.017111  0.026788  44.956099  28.962752
# 23  0.005632  0.610699  0.016862  0.023370  42.416923  28.088631
# 24  0.005787  0.681367  0.016463  0.025281  50.603865  30.305110
# 25  0.005670  0.608853  0.023054  0.023162  71.544595  30.237712
# 26  0.005800  0.561486  0.028687  0.025198  66.893201  32.093945
# 27  0.004659  0.464268  0.033672  0.020817  46.004964  25.454749
# 28  0.005281  0.424692  0.041347  0.020489  49.708739  25.933269
# 29  0.004597  0.420210  0.040135  0.017479  43.274168  25.608954
# 30  0.004008  0.375490  0.029176  0.014341  33.581906  19.426194
# 31  0.004014  0.393995  0.030362  0.015415  35.393423  18.402730
# 32  0.003568  0.391693  0.028788  0.017167  29.161240  16.946910
# 33  0.003893  0.487397  0.025785  0.022433  47.239341  22.549382
# 34  0.003899  0.546031  0.016636  0.022764  36.366787  27.186033
# 35  0.004838  0.663621  0.014110  0.025834  47.923335  29.476819
# 36  0.005076  0.605070  0.018763  0.024125  47.575200  30.755598
# 37  0.004903  0.545255  0.024581  0.022057  46.168851  27.798199
# 38  0.004794  0.506114  0.029233  0.024167  57.803706  32.513932
# 39  0.004575  0.465771  0.036895  0.022375  64.403175  27.761792
# 40  0.004698  0.430174  0.044413  0.019847  52.927588  27.037695
# 41  0.004176  0.395514  0.039019  0.017204  40.791388  25.217701
# 42  0.004013  0.360968  0.027652  0.014847  28.979823  17.764658
# 43  0.003819  0.392712  0.033481  0.014927  32.292188  17.521669
# 44  0.003495  0.423382  0.028448  0.016777  35.435399  19.865357
# 45  0.003481  0.445077  0.021328  0.019880  37.819391  20.295502
# 46  0.004121  0.573455  0.017680  0.025216  50.900743  29.780329
# 47  0.004448  0.627756  0.015368  0.025609  45.495887  28.887572
# 48  0.004557  0.604110  0.020318  0.024151  49.846628  31.250322
# 49  0.004518  0.548445  0.025975  0.022949  44.529153  27.629614
# 50  0.004720  0.537483  0.033275  0.024158  55.606118  34.200162
# 51  0.004344  0.456615  0.040835  0.020014  55.304463  25.855078
# 52  0.004543  0.423487  0.043576  0.018773  59.775921  25.358686
# 53  0.004231  0.411696  0.043669  0.016476  40.725553  23.749029
# 54  0.003648  0.386241  0.030164  0.014218  33.355995  19.487714
# 55  0.003328  0.377373  0.027027  0.013455  25.332108  14.080407
# 56  0.003335  0.438518  0.031127  0.017307  36.100323  19.931053
# 57  0.003160  0.416195  0.024082  0.017566  32.656892  17.961219
# 58  0.003882  0.533659  0.019694  0.023873  47.839871  27.502471
# 59  0.004118  0.592382  0.017458  0.024243  45.389124  28.433215

# %%
values = ss_2.values # 대기오염 수치들만 array로 변경
dates = ss_1['연월']
data = pd.DataFrame(values, index=dates, columns=['SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'])

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=90)
sns.lineplot(data=data, linewidth=2.5)

# %% [markdown]
# #### 상관관계 분석

# %%
train_data.head()
# Out:
#            일시  도_num    연도       SO2        CO        O3       NO2       PM10  \
# 0  2013-01-01      0  2013  0.007216  0.770076  0.020583  0.018420  45.132576
# 1  2013-01-01      1  2013  0.006340  0.649199  0.013143  0.031923  44.532051
# 2  2013-01-01      2  2013  0.007477  0.713492  0.013913  0.030154  39.626984
# 3  2013-01-01      3  2013  0.005741  0.658125  0.008458  0.043541  38.334375
# 4  2013-01-01      4  2013  0.006363  0.739583  0.015653  0.017980  48.280093
#
#         PM25  합계 일조시간(hr)        품종명      도   마켓명  가격       연월
# 0  31.543635     3.115385  토마토(10kg)    강원도  가락도매 NaN  2013-01
# 1  31.543635     3.800000  토마토(10kg)    경기도  가락도매 NaN  2013-01
# 2  31.543635     5.533333  토마토(10kg)  인천광역시  가락도매 NaN  2013-01
# 3  31.543635     4.600000  토마토(10kg)  서울특별시  가락도매 NaN  2013-01
# 4  31.543635     2.686667  토마토(10kg)   경상북도  북부도매 NaN  2013-01

# %%
# 분석에 사용할 독립변수 컬럼 따로 빼기
tom_f = train_data.iloc[:,3:10]
tom_f
# Out:
#             SO2        CO        O3       NO2       PM10       PM25  \
# 0      0.007216  0.770076  0.020583  0.018420  45.132576  31.543635
# 1      0.006340  0.649199  0.013143  0.031923  44.532051  31.543635
# 2      0.007477  0.713492  0.013913  0.030154  39.626984  31.543635
# 3      0.005741  0.658125  0.008458  0.043541  38.334375  31.543635
# 4      0.006363  0.739583  0.015653  0.017980  48.280093  31.543635
# ...         ...       ...       ...       ...        ...        ...
# 27385  0.003583  0.700260  0.028560  0.017779  69.770833  34.403416
# 27386  0.003392  0.557803  0.029622  0.013610  71.634133  31.628244
# 27387  0.002731  0.600926  0.027796  0.016380  79.917069  31.310185
# 27388  0.003782  0.399265  0.028774  0.014218  78.670238  38.210317
# 27389  0.003821  0.625893  0.031497  0.009815  63.358709  29.200649
#
#        합계 일조시간(hr)
# 0         3.115385
# 1         3.800000
# 2         5.533333
# 3         4.600000
# 4         2.686667
# ...            ...
# 27385     8.800000
# 27386     7.985714
# 27387     6.100000
# 27388     8.900000
# 27389     6.085714
#
# [27390 rows x 7 columns]

# %%
# 변수끼리의 상관관계 계산
corr = tom_f.corr()

# 삼각 행렬 모양으로 만들기
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# 컬러맵 지정
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# 상관관계 계수를 히트맵 그래프로 나타낸다.
plt.figure(figsize=(7,6))
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## 4. 다양한 머신러닝 시도

# %% [markdown]
# ### 1) 변수 선택: PCA(주성분 분석)

# %%
from sklearn.preprocessing import StandardScaler # 데이터 표준화 위해 설치
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA # PCA 하기 위해 설치

# %%
# 데이터의 스케일을 맞추기 위해 표준화 한다.
tomato_std = StandardScaler().fit_transform(tom_f)
# tomato_std = Normalizer().fit_transform(tom_f)

tomato_std = pd.DataFrame(tomato_std)
tomato_std.columns= ['SO2','CO','O3','NO2','PM10','PM25','합계 일조시간(hr)']
tomato_std
# Out:
#             SO2        CO        O3       NO2      PM10      PM25  합계 일조시간(hr)
# 0      1.297766  1.624683 -0.602105 -0.234635 -0.024019  0.727145    -0.883299
# 1      0.868943  0.917759 -1.221802  1.096793 -0.049325  0.727145    -0.703041
# 2      1.425758  1.293765 -1.157707  0.922361 -0.256019  0.727145    -0.246658
# 3      0.575192  0.969962 -1.612004  2.242284 -0.310489  0.727145    -0.492403
# 4      0.880083  1.446355 -1.012774 -0.278056  0.108614  0.727145    -0.996180
# ...         ...       ...       ...       ...       ...       ...          ...
# 27385 -0.481691  1.216382  0.062268 -0.297919  1.014212  1.040605     0.613449
# 27386 -0.575264  0.383249  0.150704 -0.708992  1.092729  0.736419     0.399049
# 27387 -0.899023  0.635445 -0.001333 -0.435809  1.441764  0.701557    -0.097456
# 27388 -0.384429 -0.543930  0.080085 -0.648984  1.389224  1.457877     0.639779
# 27389 -0.365045  0.781459  0.306903 -1.083110  0.744011  0.470332    -0.101217
#
# [27390 rows x 7 columns]

# %%
# 공분산 행렬 구하기
tom_cov = np.cov(tomato_std.T)
tom_cov
# Out:
# array([[ 1.00003651,  0.51971794, -0.08212576,  0.51969242,  0.43148246,
#          0.30450038,  0.09457477],
#        [ 0.51971794,  1.00003651, -0.35795093,  0.67097896,  0.55477136,
#          0.500115  , -0.10751782],
#        [-0.08212576, -0.35795093,  1.00003651, -0.43031651,  0.11837831,
#         -0.034791  ,  0.36520248],
#        [ 0.51969242,  0.67097896, -0.43031651,  1.00003651,  0.43828669,
#          0.3717405 , -0.00231155],
#        [ 0.43148246,  0.55477136,  0.11837831,  0.43828669,  1.00003651,
#          0.53796655,  0.11594298],
#        [ 0.30450038,  0.500115  , -0.034791  ,  0.3717405 ,  0.53796655,
#          1.00003651,  0.01466716],
#        [ 0.09457477, -0.10751782,  0.36520248, -0.00231155,  0.11594298,
#          0.01466716,  1.00003651]])

# %%
# 고유값과 고유벡터 계산 (고유분해)
eig_vals, eig_vecs= np.linalg.eig(tom_cov)

# 고유값 확인
eig_vals
# Out:
# array([3.02565344, 1.51882335, 0.84697116, 0.60950099, 0.43806389,
#        0.26976279, 0.29147996])

# %%
# 고유벡터 확인
eig_vecs
# Out:
# array([[-0.40429172, -0.12982074,  0.37027522, -0.64825982,  0.4674034 ,
#          0.19932956,  0.06443629],
#        [-0.50418616,  0.11061459, -0.02352074,  0.02214889, -0.19112898,
#         -0.58040094,  0.59926738],
#        [ 0.19101636, -0.66620905, -0.23116876, -0.35332422, -0.06857245,
#         -0.52643305, -0.24406418],
#        [-0.47230728,  0.15124836,  0.32377465,  0.15636089, -0.20046771,
#         -0.24857513, -0.72304503],
#        [-0.41676413, -0.33781918, -0.29200787, -0.09286493, -0.58136944,
#          0.52857438,  0.03020047],
#        [-0.38578211, -0.18369401, -0.52819391,  0.40566305,  0.60087418,
#          0.02509565, -0.11044361],
#        [ 0.01621501, -0.59693814,  0.58293792,  0.50674993,  0.03277328,
#          0.0667866 ,  0.20311396]])

# %%
# 주성분의 고유값 비율 확인
eig_vals_sum = np.sum(eig_vals)
for eig_val in eig_vals:
    print (str(eig_val/eig_vals_sum))
# Out:
# 0.4322204248822301
# 0.2169668432177172
# 0.1209914619425564
# 0.0870683908342937
# 0.0625782704215688
# 0.03853613491381767
# 0.04163847378781622

# %%
# 위 데이터를 이용해 scree plot 그려서 고유값 확인. 주성분 개수를 정할 때 한 눈에 볼 수 있어서 좋다.
sing_vals = np.arange(len(eig_vals))+1
plt.plot(sing_vals, eig_vals, "ro-", linewidth=2)
plt.title("Scree Plot")
plt.xlabel("Principal Component")
plt.ylabel("Eig_values")
plt.show()

# %%
# 주성분의 개수를 4개로 하여 주성분 분석
pca = PCA(n_components = 4)
pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=4, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
# 각 주성분 데이터들을 찾아서 array로 만든다.
pca_values = pca.fit_transform(tomato_std)
pca_values
# Out:
# array([[ 1.63284284, -0.77869333,  0.38643263,  0.77965908],
#        [ 1.83679762, -1.27133696, -0.15821799, -0.00350474],
#        [ 2.06331896, -0.96895213, -0.61065509,  0.14858166],
#        ...,
#        [ 0.62443747,  0.43577851,  1.33700301, -0.63052329],
#        [ 0.37954703,  1.28078903,  1.16094323, -0.8939956 ],
#        [ 0.16939579,  0.51176733,  1.09986434, -0.04657205]])

# %%
# 고유값의 누적 설명력 확인. 80% 넘는것을 확인할 수 있다.
sum(pca.explained_variance_ratio_)
# Out:
# 0.857247120876797

# %%
# 위에서 구한 주성분으로 이루어진 데이터 프레임 생성
pcadf = pd.DataFrame(data=pca_values, columns = ['PC1', 'PC2','PC3','PC4'])
pcadf
# Out:
#             PC1       PC2       PC3       PC4
# 0      1.632843 -0.778693  0.386433  0.779659
# 1      1.836798 -1.271337 -0.158218 -0.003505
# 2      2.063319 -0.968952 -0.610655  0.148582
# 3      2.247657 -1.710944 -0.708356 -0.643060
# 4      1.489110 -1.102792  0.560553  0.444051
# ...         ...       ...       ...       ...
# 27385  1.080123  0.789424  0.806017 -0.909434
# 27386  0.330043  0.833188  0.961849 -0.616783
# 27387  0.624437  0.435779  1.337003 -0.630523
# 27388  0.379547  1.280789  1.160943 -0.893996
# 27389  0.169396  0.511767  1.099864 -0.046572
#
# [27390 rows x 4 columns]

# %%
t1 = train_data.iloc[:,0:3]
t2 = train_data.iloc[:, -4:]

# %%
# 데이터 병합 후 확인
tom_fin = pd.concat([t1, pcadf ,t2], axis=1)
tom_fin
# Out:
#                일시  도_num    연도       PC1       PC2       PC3       PC4      도  \
# 0      2013-01-01      0  2013  1.632843 -0.778693  0.386433  0.779659    강원도
# 1      2013-01-01      1  2013  1.836798 -1.271337 -0.158218 -0.003505    경기도
# 2      2013-01-01      2  2013  2.063319 -0.968952 -0.610655  0.148582  인천광역시
# 3      2013-01-01      3  2013  2.247657 -1.710944 -0.708356 -0.643060  서울특별시
# 4      2013-01-01      4  2013  1.489110 -1.102792  0.560553  0.444051   경상북도
# ...           ...    ...   ...       ...       ...       ...       ...    ...
# 27385  2017-12-31     10  2017  1.080123  0.789424  0.806017 -0.909434  울산광역시
# 27386  2017-12-31     11  2017  0.330043  0.833188  0.961849 -0.616783   경상남도
# 27387  2017-12-31     12  2017  0.624437  0.435779  1.337003 -0.630523  광주광역시
# 27388  2017-12-31     13  2017  0.379547  1.280789  1.160943 -0.893996  부산광역시
# 27389  2017-12-31     14  2017  0.169396  0.511767  1.099864 -0.046572   전라남도
#
#         마켓명  가격       연월
# 0      가락도매 NaN  2013-01
# 1      가락도매 NaN  2013-01
# 2      가락도매 NaN  2013-01
# 3      가락도매 NaN  2013-01
# 4      북부도매 NaN  2013-01
# ...     ...  ..      ...
# 27385  엄궁도매 NaN  2017-12
# 27386  엄궁도매 NaN  2017-12
# 27387  각화도매 NaN  2017-12
# 27388  엄궁도매 NaN  2017-12
# 27389  각화도매 NaN  2017-12
#
# [27390 rows x 11 columns]

# %%
# 데이터 저장
# tom_fin.to_csv('tom1317_fin.csv',encoding = 'cp949', index=False)

# %%
# 저장된 데이터 확인
# pd.read_csv('tom1317_fin.csv', encoding = 'cp949')

# %% [markdown]
# ### 3) 머신러닝 적용

# %% [markdown]
# #### 필요한 라이브러리 불러오기

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRFRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import import_ipynb
from functions import date_time,factorize,data_preparation

# %% [markdown]
# #### 머신러닝 전처리

# %%
df = pd.read_csv('E:/Learning_Spoons_Second_Project/data/tom1317_fin.csv',encoding='cp949')
df_2 = pd.read_csv('E:/Learning_Spoons_Second_Project/data/tom18_fin.csv',encoding='cp949')

# %%
data_preparation(df)
data_preparation(df_2)

# %%
df_label = df['가격']
df = df.drop(['품종명','도','일시','마켓명','가격'],axis=1)

# %%
df_2_label = df_2['가격']
df_2 = df_2.drop(['품종명','도','일시','마켓명','가격'],axis=1)

# %%
X_train,X_valid,y_train, y_valid = train_test_split(df, df_label, test_size = 0.3, random_state = 234)

# %% [markdown]
# #### XG boost

# %%
# xgboost grid search
xgb= XGBRFRegressor(silent=True,n_jobs=-1,n_estimators=1000)

# %%
params = {'learning_rate' : [0.01,0.03,0.05],
        'min_child_weight': [1,3],
        'gamma': [0.5, 1, 1.5,],
        'subsample': [0.6, 0.8],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

# %%
xgb_ran = GridSearchCV(xgb,param_grid=params,scoring='neg_mean_squared_error',
                       n_jobs=-1,cv=skf.split(X_train,y_train),verbose=3)
xgb_ran.fit(X_train,y_train)

# %%
np.sqrt(-xgb_ran.best_score_)

# %% [markdown]
# #### Random Forest

# %%
n_estimators = [int(x) for x in np.linspace(start= 700, stop = 1500, num=8)]
max_features = ['auto','sqrt']
max_depth = [int(x) for x in np.linspace(1,5, num=4)]
max_depth.append(None)
min_samples_split = [2,5,10]
min_samples_leaf = [1,2,4]

# %%
grid_search = {'n_estimators': n_estimators,
              'max_features':max_features,
              'max_depth':max_depth,
              'min_samples_split':min_samples_split,
              'min_samples_leaf':min_samples_leaf
              }

numFolds = 3
skf =StratifiedKFold(shuffle = True, n_splits = numFolds,random_state=42)

rf = RandomForestRegressor()

clf = GridSearchCV(rf,
                    param_grid= grid_search,
                    cv = skf.split(X_train,y_train),
                    scoring='neg_mean_squared_error',
                    verbose=3,
                    n_jobs = - 1)

# %%
clf.fit(X_train,y_train)

# %%
np.sqrt(-clf.best_score_)

# %% [markdown]
# #### 선형회귀

# %%
mlr = LinearRegression(n_jobs=-1)
mlr.fit(X_train,y_train)

# %%
predicted = mlr.predict(X_valid)

# %%
a = plt.scatter(y_valid,predicted,alpha=0.4)
plt.savefig('scatter.png')

# %%
mlr.score(X_train,y_train)

# %% [markdown]
# #### Decision Tree

# %%
regressor = DecisionTreeRegressor(random_state=42,min_samples_leaf=5,max_features= 8)

# %%
regressor.fit(X_train,y_train)

# %%
mean_squared_error(regressor.predict(df_2),df_2_label)

# %% [markdown]
# #### ARIMA

# %%
from datetime import date, timedelta
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm

# %%
tm = pd.read_csv('full_data_ver2.csv')
tm

# %%
tm.info()

# %%
tm1 = tm.groupby(['일시']).mean()
tm1 = tm1.reset_index()
tm1

# %%
tm1['연월'] = tm1['일시'].str.split("-").str.get(0) + '-' + tm1['일시'].str.split("-").str.get(1)
tm1

# %%
tm2 = tm1.groupby(['연월'])['가격'].mean()
tm2 = pd.DataFrame(tm2)
tm2 = tm2.reset_index()
tm2

# %%
decomposition = seasonal_decompose(pd.to_datetime(tm2['연월']), freq=12)  
fig = plt.figure()  
fig = decomposition.plot()

# %%
def test_stationarity(tm2):

    #Determing rolling statistics
    rolmean = tm2.rolling(12).mean()
    rolstd = tm2.rolling(12).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(10, 6))
    orig = plt.plot(tm2, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')

    plt.legend(loc='best'); plt.title('Rolling Mean & Standard Deviation')
    plt.show()

    #Perform Dickey-Fuller test:
    print ('<Results of Dickey-Fuller Test>')
    dftest = adfuller(tm2, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4],
                         index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(tm2['가격'])

# %%
tm2['first_difference'] = tm2['가격'] - tm2['가격'].shift(1)  
# Or Alternatively,
# df.diff().plot()
test_stationarity(tm2.first_difference.dropna(inplace=False))

# %%
tm2['seasonal_first_difference'] = tm2['first_difference'] - tm2['first_difference'].shift(12)  
test_stationarity(tm2.seasonal_first_difference.dropna(inplace=False))

# %%
fig = plt.figure(figsize=(8,7))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(tm2.seasonal_first_difference.iloc[13:], lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(tm2.seasonal_first_difference.iloc[13:],lags=40,ax=ax2)

# %%
mod = sm.tsa.SARIMAX(tm2['가격'], trend='ct',order=(0,1,0), seasonal_order=(1,1,1,12))
results = mod.fit()
print (results.summary())

# %%
tm2['forecast'] = results.predict(start = len(tm2)-12, end= len(tm2), dynamic= True)  
tm2[['가격', 'forecast']].plot()
# tm2[-12:]

# %% [markdown]
# #### VAR 모형

# %%
# VAR 모형 돌리기 위해 필요한 패키지 설치
from statsmodels.tsa.vector_ar.var_model import VARProcess
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.api import VAR
import statsmodels.api as sm

# %%
# 서울특별시 13-17년 데이터 잘라서 모형에 쓰기
seoul = pd.read_csv('도_분할/서울특별시.csv')
seoul1317 = seoul[seoul['일시'].str.contains('2013|2014|2015|2016|2017')]
seoul1317.plot()
plt.show()

# %%
seoul1317.head(20)
# Out:
#     Unnamed: 0          일시  도_num    연도       SO2        CO        O3  \
# 0            3  2013-01-01      3  2013  0.005741  0.658125  0.008458
# 1           18  2013-01-02      3  2013  0.004950  0.403021  0.024425
# 2           33  2013-01-03      3  2013  0.006396  0.512396  0.018154
# 3           48  2013-01-04      3  2013  0.007002  0.738021  0.008473
# 4           63  2013-01-05      3  2013  0.007673  1.020625  0.003945
# 5           78  2013-01-06      3  2013  0.009809  1.138958  0.008473
# 6           93  2013-01-07      3  2013  0.008350  1.094792  0.006366
# 7          108  2013-01-08      3  2013  0.009403  1.091354  0.010590
# 8          123  2013-01-09      3  2013  0.006489  0.517500  0.019678
# 9          138  2013-01-10      3  2013  0.007560  0.706562  0.011363
# 10         153  2013-01-11      3  2013  0.008053  0.968542  0.003439
# 11         168  2013-01-12      3  2013  0.012139  1.156979  0.003913
# 12         183  2013-01-13      3  2013  0.011048  1.660833  0.003966
# 13         198  2013-01-14      3  2013  0.009680  1.411875  0.008815
# 14         213  2013-01-15      3  2013  0.011346  1.356562  0.004678
# 15         228  2013-01-16      3  2013  0.009828  1.111250  0.008833
# 16         243  2013-01-17      3  2013  0.011286  1.058437  0.014458
# 17         258  2013-01-18      3  2013  0.007294  0.800625  0.009766
# 18         273  2013-01-19      3  2013  0.012648  1.037708  0.006805
# 19         288  2013-01-20      3  2013  0.012049  1.145104  0.007918
#
#          NO2        PM10       PM25  합계 일조시간(hr)        품종명      도   마켓명  \
# 0   0.043541   38.334375  31.543635          4.6  토마토(10kg)  서울특별시  가락도매
# 1   0.021413   18.644792  37.602906          9.1  토마토(10kg)  서울특별시  가락도매
# 2   0.028391   29.743750  35.062375          9.1  토마토(10kg)  서울특별시  가락도매
# 3   0.047785   45.383333  37.749110          9.2  토마토(10kg)  서울특별시  가락도매
# 4   0.065136   62.270833  33.378771          7.5  토마토(10kg)  서울특별시  가락도매
# 5   0.055007   86.827083  23.495793          8.2  토마토(10kg)  서울특별시  가락도매
# 6   0.062664   74.414583  30.667985          5.8  토마토(10kg)  서울특별시  가락도매
# 7   0.055735   69.852083  27.463894          8.0  토마토(10kg)  서울특별시  가락도매
# 8   0.031636   33.479167  27.224864          9.3  토마토(10kg)  서울특별시  가락도매
# 9   0.046038   41.328125  20.465040          9.1  토마토(10kg)  서울특별시  가락도매
# 10  0.062516   56.134375  18.676173          6.1  토마토(10kg)  서울특별시  가락도매
# 11  0.058365  113.742708  21.760050          3.2  토마토(10kg)  서울특별시  가락도매
# 12  0.058974  158.478125  27.544423          0.6  토마토(10kg)  서울특별시  가락도매
# 13  0.057916  122.162500  33.041397          4.5  토마토(10kg)  서울특별시  가락도매
# 14  0.067449  116.821875  34.787800          4.1  토마토(10kg)  서울특별시  가락도매
# 15  0.057443   96.410417  51.397836          4.0  토마토(10kg)  서울특별시  가락도매
# 16  0.043931  112.554167  44.381827          7.3  토마토(10kg)  서울특별시  가락도매
# 17  0.054093   56.372917  50.173131          9.3  토마토(10kg)  서울특별시  가락도매
# 18  0.062257   79.691667  43.688865          6.5  토마토(10kg)  서울특별시  가락도매
# 19  0.057155  106.654167  42.560117          0.4  토마토(10kg)  서울특별시  가락도매
#
#               가격
# 0   29000.000000
# 1   29000.000000
# 2   30000.000000
# 3   30000.000000
# 4   30000.000000
# 5   30000.000000
# 6   30000.000000
# 7   27000.000000
# 8   27000.000000
# 9   27000.000000
# 10  27000.000000
# 11  26333.333333
# 12  25666.666667
# 13  25000.000000
# 14  25000.000000
# 15  28000.000000
# 16  28000.000000
# 17  28000.000000
# 18  28666.666667
# 19  29333.333333

# %%
m2 = sm.tsa.VAR(seoul1317[['SO2','CO','O3','NO2','PM10','PM25','합계 일조시간(hr)','가격']])
r = m2.fit()
print(r.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 25, Mar, 2020
# Time:                     18:52:05
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                   -13.6905
# Nobs:                     1825.00    HQIC:                  -13.8277
# Log likelihood:          -7953.60    FPE:                9.11805e-07
# AIC:                     -13.9078    Det(Omega_mle):     8.76618e-07
# --------------------------------------------------------------------
# Results for equation SO2
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.001360         0.000156            8.741           0.000
# L1.SO2                 0.669621         0.025123           26.654           0.000
# L1.CO                  0.000511         0.000277            1.843           0.065
# L1.O3                 -0.012487         0.003072           -4.065           0.000
# L1.NO2                -0.008684         0.003519           -2.467           0.014
# L1.PM10               -0.000003         0.000001           -2.689           0.007
# L1.PM25                0.000010         0.000003            3.121           0.002
# L1.합계 일조시간(hr)         0.000066         0.000007           10.077           0.000
# L1.가격                  0.000000         0.000000            2.044           0.041
# =================================================================================
#
# Results for equation CO
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.178221         0.020693            8.613           0.000
# L1.SO2                12.863555         3.340709            3.851           0.000
# L1.CO                  0.608851         0.036855           16.520           0.000
# L1.O3                 -3.399428         0.408518           -8.321           0.000
# L1.NO2                -1.348191         0.467972           -2.881           0.004
# L1.PM10               -0.000266         0.000161           -1.648           0.099
# L1.PM25                0.000742         0.000435            1.707           0.088
# L1.합계 일조시간(hr)         0.009688         0.000871           11.126           0.000
# L1.가격                  0.000001         0.000000            2.208           0.027
# =================================================================================
#
# Results for equation O3
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.006630         0.001073            6.177           0.000
# L1.SO2                -0.459352         0.173262           -2.651           0.008
# L1.CO                 -0.007547         0.001911           -3.948           0.000
# L1.O3                  0.783958         0.021187           37.001           0.000
# L1.NO2                 0.254260         0.024271           10.476           0.000
# L1.PM10                0.000010         0.000008            1.158           0.247
# L1.PM25               -0.000034         0.000023           -1.502           0.133
# L1.합계 일조시간(hr)        -0.000359         0.000045           -7.945           0.000
# L1.가격                 -0.000000         0.000000           -4.174           0.000
# =================================================================================
#
# Results for equation NO2
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.011455         0.001428            8.019           0.000
# L1.SO2                 0.796564         0.230595            3.454           0.001
# L1.CO                 -0.001603         0.002544           -0.630           0.529
# L1.O3                 -0.137557         0.028198           -4.878           0.000
# L1.NO2                 0.439170         0.032302           13.596           0.000
# L1.PM10                0.000001         0.000011            0.110           0.912
# L1.PM25                0.000058         0.000030            1.919           0.055
# L1.합계 일조시간(hr)         0.000934         0.000060           15.538           0.000
# L1.가격                  0.000000         0.000000            1.845           0.065
# =================================================================================
#
# Results for equation PM10
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -5.606782         3.429727           -1.635           0.102
# L1.SO2              2024.325824       553.691111            3.656           0.000
# L1.CO                  1.487308         6.108374            0.243           0.808
# L1.O3                 91.904638        67.708100            1.357           0.175
# L1.NO2               246.083134        77.561929            3.173           0.002
# L1.PM10                0.442318         0.026704           16.563           0.000
# L1.PM25                0.144673         0.072068            2.007           0.045
# L1.합계 일조시간(hr)         0.390398         0.144320            2.705           0.007
# L1.가격                  0.000124         0.000068            1.833           0.067
# =================================================================================
#
# Results for equation PM25
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  3.435968         0.965723            3.558           0.000
# L1.SO2               592.138760       155.905278            3.798           0.000
# L1.CO                 -2.884265         1.719962           -1.677           0.094
# L1.O3                -53.084349        19.064872           -2.784           0.005
# L1.NO2                71.220755        21.839459            3.261           0.001
# L1.PM10               -0.025119         0.007519           -3.341           0.001
# L1.PM25                0.712707         0.020292           35.122           0.000
# L1.합계 일조시간(hr)         0.160811         0.040637            3.957           0.000
# L1.가격                  0.000022         0.000019            1.154           0.248
# =================================================================================
#
# Results for equation 합계 일조시간(hr)
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  4.054899         0.598215            6.778           0.000
# L1.SO2               116.711909        96.575180            1.209           0.227
# L1.CO                 -2.099642         1.065427           -1.971           0.049
# L1.O3                 48.019276        11.809693            4.066           0.000
# L1.NO2               -19.594060        13.528404           -1.448           0.148
# L1.PM10                0.004759         0.004658            1.022           0.307
# L1.PM25                0.026507         0.012570            2.109           0.035
# L1.합계 일조시간(hr)         0.209451         0.025172            8.321           0.000
# L1.가격                  0.000032         0.000012            2.713           0.007
# =================================================================================
#
# Results for equation 가격
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                590.401316       192.439142            3.068           0.002
# L1.SO2            -56527.989427     31067.152141           -1.820           0.069
# L1.CO                840.109123       342.735828            2.451           0.014
# L1.O3              -6712.807808      3799.045713           -1.767           0.077
# L1.NO2             -7524.352723      4351.935918           -1.729           0.084
# L1.PM10               -0.734532         1.498367           -0.490           0.624
# L1.PM25                1.151437         4.043649            0.285           0.776
# L1.합계 일조시간(hr)         6.790641         8.097650            0.839           0.402
# L1.가격                  0.985065         0.003794          259.663           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                     SO2        CO        O3       NO2      PM10      PM25  합계 일조시간(hr)        가격
# SO2            1.000000  0.607652 -0.044695  0.547663  0.483659  0.307742     0.083101  0.006199
# CO             0.607652  1.000000 -0.350402  0.829355  0.503539  0.456289    -0.167849  0.019319
# O3            -0.044695 -0.350402  1.000000 -0.469886  0.072834  0.014980     0.400594 -0.015649
# NO2            0.547663  0.829355 -0.469886  1.000000  0.360532  0.350237    -0.077040 -0.008583
# PM10           0.483659  0.503539  0.072834  0.360532  1.000000  0.509180     0.011227 -0.003717
# PM25           0.307742  0.456289  0.014980  0.350237  0.509180  1.000000    -0.069293  0.020703
# 합계 일조시간(hr)    0.083101 -0.167849  0.400594 -0.077040  0.011227 -0.069293     1.000000 -0.015106
# 가격             0.006199  0.019319 -0.015649 -0.008583 -0.003717  0.020703    -0.015106  1.000000

# %%
fig = r.plot_forecast(steps=100, alpha=0.05, plot_stderr=True)
plt.tight_layout()
plt.legend(bbox_to_anchor=(1.05,1.05), scatterpoints=1 )
plt.show()

# %%
irf = r.irf(10)

# %%
plt.figure(figsize=(25,25))
irf.plot()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### keras를 사용한 회귀 분석

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('일별그룹_data.csv')

# %%
df.columns
# Out:
# Index(['일시', '도_num', '연도', 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
#        '합계 일조시간(hr)', '가격'],
#       dtype='object')

# %%
df['일시'] = df['일시'].str.replace('-', '')

# %%
df = df[['일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25', '합계 일조시간(hr)', '가격']]
df
# Out:
#             일시       SO2        CO        O3       NO2       PM10       PM25  \
# 0     20130101  0.008055  0.705943  0.014508  0.027351  53.793694  31.543635
# 1     20130102  0.006252  0.458401  0.024726  0.015768  39.865292  37.602906
# 2     20130103  0.005165  0.443746  0.021831  0.017571  26.996650  35.062375
# 3     20130104  0.006058  0.627333  0.015143  0.029622  39.964823  37.749110
# 4     20130105  0.006336  0.745207  0.014486  0.034354  46.933748  33.378771
# ...        ...       ...       ...       ...       ...        ...        ...
# 2186  20181227  0.003160  0.363920  0.026685  0.011358  23.527415   8.619631
# 2187  20181228  0.003313  0.423625  0.020198  0.015384  31.120399  13.709885
# 2188  20181229  0.003445  0.426891  0.023384  0.013958  34.862185  13.486144
# 2189  20181230  0.003624  0.487516  0.021316  0.016805  28.162086  17.005345
# 2190  20181231  0.004105  0.625011  0.013296  0.027348  39.986771  26.140318
#
#       합계 일조시간(hr)            가격
# 0        4.233391  28800.000000
# 1        8.012553  28800.000000
# 2        8.083956  29066.666667
# 3        8.738554  29066.666667
# 4        7.676589  29066.666667
# ...           ...           ...
# 2186     8.232046  30600.000000
# 2187     7.523942  30800.000000
# 2188     8.279665  30333.333333
# 2189     8.420759  29866.666667
# 2190     7.691821  29400.000000
#
# [2191 rows x 9 columns]

# %%
train_dataset = df[~df['일시'].str.contains('2018')]
test_dataset = df[df['일시'].str.contains('2018')]

# %%
train_stats = train_dataset.describe()
train_stats.pop("가격")
# Out:
# count     1826.000000
# mean     26368.008397
# std       7519.861446
# min      12866.666667
# 25%      19466.666667
# 50%      27555.555556
# 75%      32333.333333
# max      42666.666667
# Name: 가격, dtype: float64

# %%
train_stats = train_stats.transpose()
train_stats
# Out:
#               count       mean        std        min        25%        50%  \
# SO2          1826.0   0.004567   0.001245   0.002447   0.003687   0.004303
# CO           1826.0   0.492271   0.144205   0.248684   0.390934   0.453541
# O3           1826.0   0.027812   0.010607   0.006075   0.019519   0.026829
# NO2          1826.0   0.020800   0.006971   0.007169   0.015669   0.019076
# PM10         1826.0  45.702578  21.477901  10.698345  31.439913  42.234049
# PM25         1826.0  24.909677   8.447454   7.805669  18.779871  23.933758
# 합계 일조시간(hr)  1826.0   6.470134   3.303467   0.002422   4.032981   7.102630
#
#                    75%         max
# SO2           0.005110    0.011325
# CO            0.565250    1.328210
# O3            0.035027    0.072478
# NO2           0.025543    0.047221
# PM10         54.527344  333.112887
# PM25         29.893482   69.185941
# 합계 일조시간(hr)   9.015018   13.009882

# %%
train_labels = train_dataset.pop('가격')
test_labels = test_dataset.pop('가격')

# %%
train_dataset1 = train_dataset.set_index('일시')
test_dataset1 = test_dataset.set_index('일시')

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset1)
normed_test_data = norm(test_dataset1)

# %%
train_dataset.keys()
# Out:
# Index(['일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25', '합계 일조시간(hr)'], dtype='object')

# %%
len(train_dataset.keys())
# Out:
# 8

# %%
def build_model():
    model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(normed_train_data.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

    optimizer = tf.keras.optimizers.RMSprop(0.001)

    model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                512
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = normed_train_data
example_result = model.predict(example_batch)
example_result
# Out:
# array([[-1.0620165 ],
#        [-0.31775832],
#        [-0.21956411],
#        ...,
#        [-0.36498588],
#        [-0.2865311 ],
#        [-0.19054835]], dtype=float32)

# %%
mean_squared_error(example_result,train_labels)
# Out:
# 751802251.2911103

# %%
normed_test_data
# Out:
#                SO2        CO        O3       NO2      PM10      PM25  \
# 일시
# 20180101 -0.213157  0.691187 -0.774983 -0.156064 -0.080181 -0.165263
# 20180102  0.170781  1.759052 -1.122142  0.797127  0.650630  1.193730
# 20180103 -0.217278  0.017330 -0.698456 -0.316368 -0.645091 -0.425436
# 20180104  0.001623  0.298517 -1.132325  0.527586 -0.305426  0.169585
# 20180105  0.015702  0.739740 -1.125366  0.962115  0.043770  0.793062
# ...            ...       ...       ...       ...       ...       ...
# 20181227 -1.129111 -0.890060 -0.106261 -1.354464 -1.032464 -1.928397
# 20181228 -1.006434 -0.476030 -0.717917 -0.776918 -0.678939 -1.325819
# 20181229 -0.900824 -0.453382 -0.417515 -0.981514 -0.504723 -1.352305
# 20181230 -0.756432 -0.032975 -0.612442 -0.573009 -0.816676 -0.935706
# 20181231 -0.370428  0.920492 -1.368631  0.939325 -0.266125  0.145682
#
#           합계 일조시간(hr)
# 일시
# 20180101     0.593158
# 20180102    -0.197855
# 20180103     0.542527
# 20180104    -0.439961
# 20180105     0.037200
# ...               ...
# 20181227     0.533352
# 20181228     0.319001
# 20181229     0.547767
# 20181230     0.590478
# 20181231     0.369820
#
# [365 rows x 7 columns]

# %%
# 에포크가 끝날 때마다 점(.)을 출력해 훈련 진행 과정을 표시합니다
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

EPOCHS = 1000

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#              loss          mae         mse      val_loss      val_mae  \
# 995  4.519768e+07  5769.042969  45197672.0  5.560964e+07  6370.851074
# 996  4.517982e+07  5764.982910  45179824.0  5.534215e+07  6367.523438
# 997  4.519355e+07  5766.140625  45193560.0  5.544646e+07  6366.324219
# 998  4.518280e+07  5763.389160  45182804.0  5.538156e+07  6366.292969
# 999  4.517945e+07  5765.240234  45179456.0  5.553575e+07  6368.191406
#
#         val_mse  epoch
# 995  55609648.0    995
# 996  55342152.0    996
# 997  55446468.0    997
# 998  55381568.0    998
# 999  55535752.0    999

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure(figsize=(8,12))

    plt.subplot(2,1,1)
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error [가격]')
    plt.plot(hist['epoch'], hist['mae'], label='Train Error')
    plt.plot(hist['epoch'], hist['val_mae'], label = 'Val Error')
    plt.ylim([0,5])
    plt.legend()

    plt.subplot(2,1,2)
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error [$가격^2$]')
    plt.plot(hist['epoch'], hist['mse'], label='Train Error')
    plt.plot(hist['epoch'], hist['val_mse'], label = 'Val Error')
    plt.ylim([0,20])
    plt.legend()
    plt.show()

plot_history(history)
# Out:
# Font 'rm' does not have a glyph for '\uac00' [U+ac00], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uaca9' [U+aca9], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uac00' [U+ac00], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uaca9' [U+aca9], substituting with a dummy symbol.

# %%
model = build_model()

# patience 매개변수는 성능 향상을 체크할 에포크 횟수입니다
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(normed_train_data, train_labels, epochs=EPOCHS,
                    validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# ....................................................................................................
# ......................................
# Font 'rm' does not have a glyph for '\uac00' [U+ac00], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uaca9' [U+aca9], substituting with a dummy symbol.
# .
# Font 'rm' does not have a glyph for '\uac00' [U+ac00], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uaca9' [U+aca9], substituting with a dummy symbol.

# %%
loss, mae, mse = model.evaluate(normed_test_data, test_labels, verbose=2)

print("테스트 세트의 평균 절대 오차: {:5.2f} 가격".format(mae))
# Out:
# 365/365 - 0s - loss: 83023210.2630 - mae: 6389.0698 - mse: 83023208.0000
# 테스트 세트의 평균 절대 오차: 6389.07 가격

# %%
test_predictions = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [가격]')
plt.ylabel('Predictions [가격]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %% [markdown]
# ## 5. 결론

# %% [markdown]
# ### 1) 결과 문제 파악

# %% [markdown]
# * 데이터 전처리
#     - 2013년 ~ 2014년 PM25 NaN : 패턴을 고려해서 넣지 않음
#     - 마켓이 열리지 않는 일자 : 가격을 예측하기 위함이기 때문에 가격을 채워 넣어선 안됨
#
# * 피처 엔지니어링
#     - PCA 외 고민이 없음
#
# * 머신러닝 학습 데이터
#     - 일조량에 영향을 받은 토마토 재배 기간을 고려하지 않음

# %% [markdown]
# ### 2) 개선 방향

# %% [markdown]
# * 데이터 전처리
#     - 2013년 ~ 2014년 PM25 NaN : 패턴을 고려하여 NaN 채움
#     - 마켓이 열리지 않는 일자 : 휴일 주기가 같다면 이상치 처리
#
# * 피처 엔지니어링
#     - 피처 맵핑 시도
#     - 해가 땅에 닿는데 방해하는 수치 컬럼 추가
#     - 컬럼마다 모두 그래프를 그려 추세, 이상치 파악
#
# * 머신러닝 학습 데이터
#     - 재배 기간을 고려하여 학습 데이터 전처리
