# %%
import pandas as pd # 데이터 프레임
import numpy as np # 계산
import re # 정규표현식

import warnings
warnings.filterwarnings('ignore') # warning 메시지 제거

import seaborn as sns # 시각화
import graphviz # 시각화

# %%
import matplotlib.pyplot as plt

# 한글 폰트 지정
plt.rc('font', family='AppleGothic') # 맥
# plt.rc('font', family='Malgun Gothic') # 윈도우

# 마이너스 값 깨지는 현상 해결
plt.rc('axes', unicode_minus=False)

# 레티나 디스플레이 설정
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')

# %%
df = pd.read_csv('/Users/jungdayoung/Documents/GitHub/Learning_Spoons_Second_Project/data/일별그룹_data.csv')

# %%
df[~df['일시'].str.contains('2018')]
# Out:
#               일시  도_num    연도       SO2        CO        O3       NO2  \
# 0     2013-01-01      7  2013  0.008055  0.705943  0.014508  0.027351
# 1     2013-01-02      7  2013  0.006252  0.458401  0.024726  0.015768
# 2     2013-01-03      7  2013  0.005165  0.443746  0.021831  0.017571
# 3     2013-01-04      7  2013  0.006058  0.627333  0.015143  0.029622
# 4     2013-01-05      7  2013  0.006336  0.745207  0.014486  0.034354
# ...          ...    ...   ...       ...       ...       ...       ...
# 1821  2017-12-27      7  2017  0.003757  0.444184  0.021018  0.017963
# 1822  2017-12-28      7  2017  0.004966  0.656190  0.013472  0.029597
# 1823  2017-12-29      7  2017  0.005227  0.801625  0.014872  0.034964
# 1824  2017-12-30      7  2017  0.004669  0.874691  0.015140  0.034188
# 1825  2017-12-31      7  2017  0.003826  0.582864  0.026154  0.015945
#
#             PM10       PM25  합계 일조시간(hr)            가격
# 0      53.793694  31.543635     4.233391  28800.000000
# 1      39.865292  37.602906     8.012553  28800.000000
# 2      26.996650  35.062375     8.083956  29066.666667
# 3      39.964823  37.749110     8.738554  29066.666667
# 4      46.933748  33.378771     7.676589  29066.666667
# ...          ...        ...          ...           ...
# 1821   23.102752  12.274415     8.518001  22066.666667
# 1822   48.832838  28.938910     3.856231  22066.666667
# 1823   84.195141  51.171279     3.708724  22066.666667
# 1824  107.461279  69.185941     1.940541  22016.666667
# 1825   69.495012  34.368856     7.838237  21966.666667
#
# [1826 rows x 11 columns]

# %%
train_dataset = df[~df['일시'].str.contains('2018')]
test_dataset = df[df['일시'].str.contains('2018')]

# %%
train_dataset.columns
# Out:
# Index(['일시', '도_num', '연도', 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
#        '합계 일조시간(hr)', '가격'],
#       dtype='object')

# %%
sns.pairplot(train_dataset[['SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25', '합계 일조시간(hr)', '가격']], diag_kind="kde")

# %%
train_stats = train_dataset.describe()
train_stats.pop("MPG")
train_stats = train_stats.transpose()
train_stats
